# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/input/cifar-10/python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 6
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 6:
# Image - Min Value: 7 Max Value: 249
# Image - Shape: (32, 32, 3)
# Label - Label Id: 2 Name: bird

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    array =  x.flatten();
    norm=np.linalg.norm(array)
    normalized_array = x/norm
    print(normalized_array.shape)
    # TODO: Implement Function
    return normalized_array


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# (384, 32, 32, 3)
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
import sklearn
enc = sklearn.preprocessing.OneHotEncoder(sparse=False)
_,label = helper.load_cfar10_batch(cifar10_dataset_folder_path,1)
labels = np.array(label)
fitted_enc = enc.fit(labels.reshape(-1,1))

def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    
    labels = np.array(x).reshape(-1,1)
    fitted = np.array(enc.transform(labels))
    # TODO: Implement Function
    print(fitted.shape)
    return fitted


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# (869, 10)
# (5, 10)
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)
# Out:
# (9000, 32, 32, 3)
# (9000, 10)
# (9000, 32, 32, 3)
# (9000, 10)
# (9000, 32, 32, 3)
# (9000, 10)
# (9000, 32, 32, 3)
# (9000, 10)
# (9000, 32, 32, 3)
# (9000, 10)
# (5000, 32, 32, 3)
# (5000, 10)
# (10000, 32, 32, 3)
# (10000, 10)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    return  tf.placeholder(dtype=tf.float32, shape=((None,)+image_shape),name='x')



def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return  tf.placeholder(dtype=tf.float32, shape=(None,n_classes),name='y')



def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(dtype=tf.float32,name='keep_prob')


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    
    """
    # TODO: Implement Function


    image_depth = x_tensor.get_shape().as_list()[-1]
    conv2d_filter_shape = list(conv_ksize)+[image_depth,conv_num_outputs]
    conv2d_filter = tf.Variable(tf.truncated_normal(conv2d_filter_shape))
    
    bias = tf.Variable(tf.truncated_normal([conv_num_outputs],stddev=0.1))

    conv2d_strides = [1]+list(conv_strides)+[1]
    padding = "SAME"
    conv2d = tf.nn.conv2d(x_tensor, conv2d_filter, conv2d_strides,padding)
    
    conv2d_bias =tf.nn.bias_add(conv2d ,bias)
    
    conv2d_bias_relu = tf.nn.relu(conv2d_bias)
    
    max_pool_strides = [1]+list(pool_strides)+[1]
    pool_ks = [1]+list(pool_ksize)+[1]
    conv2d_max_pool = tf.nn.max_pool(conv2d_bias_relu,pool_ks,max_pool_strides,padding)
    print(conv2d_max_pool)
    
    
    return conv2d_max_pool 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tensor("MaxPool:0", shape=(?, 4, 4, 10), dtype=float32)
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    print("shape before flatten", x_tensor._shape)
    shape = x_tensor.get_shape().as_list() 
    dim = np.prod(shape[1:])
    flatten = tf.reshape(x_tensor,[-1,dim])
    print(flatten)
    
    
    # TODO: Implement Function
    return flatten


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# shape before flatten (?, 10, 30, 6)
# Tensor("Reshape:0", shape=(?, 1800), dtype=float32)
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    w = tf.Variable(tf.truncated_normal([x_tensor.get_shape().as_list()[-1],num_outputs]))
    b = tf.Variable(tf.zeros([num_outputs]))
    # TODO: Implement Function
    fully_connected = tf.matmul(x_tensor,w)+b
    fully_relu = tf.nn.relu(fully_connected)
    print("FULLY_CONNECTED",fully_relu)
    return fully_relu


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# FULLY_CONNECTED Tensor("Relu_1:0", shape=(?, 40), dtype=float32)
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    w = tf.Variable(tf.truncated_normal([x_tensor.get_shape().as_list()[-1],num_outputs],stddev=0.1))
    b = tf.Variable(tf.zeros([num_outputs]))
    # TODO: Implement Function
    output = tf.matmul(x_tensor,w)+b
    print("OUTPUT",output)
    return output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# OUTPUT Tensor("add_1:0", shape=(?, 40), dtype=float32)
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    print("input shape", x._shape)
    conv2d = conv2d_maxpool(x,32,(8,8),(1,1),(2,2),(2,2))

    conv2d = conv2d_maxpool(conv2d,64,(4,4),(1,1),(2,2),(2,2))

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    flat = flatten(conv2d)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    fully = fully_conn(flat,4096)
    fully = tf.nn.dropout(fully,keep_prob)


    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    
    out = output(fully,10)
    # TODO: return output
    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# input shape (?, 32, 32, 3)
# Tensor("MaxPool:0", shape=(?, 16, 16, 32), dtype=float32)
# Tensor("MaxPool_1:0", shape=(?, 8, 8, 64), dtype=float32)
# shape before flatten (?, 8, 8, 64)
# Tensor("Reshape:0", shape=(?, 4096), dtype=float32)
# FULLY_CONNECTED Tensor("Relu_2:0", shape=(?, 4096), dtype=float32)
# FULLY_CONNECTED Tensor("Relu_3:0", shape=(?, 1024), dtype=float32)
# OUTPUT Tensor("add_2:0", shape=(?, 10), dtype=float32)
# input shape (?, 32, 32, 3)
# Tensor("MaxPool_2:0", shape=(?, 16, 16, 32), dtype=float32)
# Tensor("MaxPool_3:0", shape=(?, 8, 8, 64), dtype=float32)
# shape before flatten (?, 8, 8, 64)
# Tensor("Reshape_4:0", shape=(?, 4096), dtype=float32)
# FULLY_CONNECTED Tensor("Relu_6:0", shape=(?, 4096), dtype=float32)
# FULLY_CONNECTED Tensor("Relu_7:0", shape=(?, 1024), dtype=float32)
# OUTPUT Tensor("add_5:0", shape=(?, 10), dtype=float32)
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    session.run(optimizer,
                      feed_dict={x: feature_batch,y:label_batch,keep_prob:keep_probability})    
    # TODO: Implement Function
    pass


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    print("accuracy ",)
    # TODO: Implement Function
    
    c = session.run(cost, feed_dict={
        x: feature_batch,
        y: label_batch,
        keep_prob: 1.0
    })
    acc = session.run(accuracy, feed_dict={
        x: valid_features,
        y: valid_labels,
        keep_prob: 1.0
    })
    print ("The cost on train set is {}".format(c))
    print ("The accuracy on this validation set is {}".format(acc))
    pass

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
import math
epochs =50

batch_size = math.ceil( math.pow(2,7))

keep_probability = 0.5

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch| {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 2.4793686866760254
# The accuracy on this validation set is 0.08399999886751175
# Epoch  2, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 2.323664426803589
# The accuracy on this validation set is 0.1111999973654747
# Epoch  3, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 2.311466932296753
# The accuracy on this validation set is 0.10279999673366547
# Epoch  4, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 2.304269313812256
# The accuracy on this validation set is 0.10300000011920929
# Epoch  5, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 2.3096299171447754
# The accuracy on this validation set is 0.10700000077486038
# Epoch  6, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 2.311890125274658
# The accuracy on this validation set is 0.10700000077486038
# Epoch  7, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 2.3030638694763184
# The accuracy on this validation set is 0.10639999806880951
# Epoch  8, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 2.303128957748413
# The accuracy on this validation set is 0.10559999942779541
# Epoch  9, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 2.303180694580078
# The accuracy on this validation set is 0.10700000077486038
# Epoch 10, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 2.303223133087158
# The accuracy on this validation set is 0.10740000009536743
# Epoch 11, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 2.3032546043395996
# The accuracy on this validation set is 0.10740000009536743
# Epoch 12, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 2.3032779693603516
# The accuracy on this validation set is 0.10740000009536743
# Epoch 13, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 2.3032965660095215
# The accuracy on this validation set is 0.10740000009536743
# Epoch 14, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 2.3033082485198975
# The accuracy on this validation set is 0.10760000348091125
# Epoch 15, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 2.3033180236816406
# The accuracy on this validation set is 0.10760000348091125
# Epoch 16, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 2.3033251762390137
# The accuracy on this validation set is 0.10760000348091125
# Epoch 17, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 2.3033289909362793
# The accuracy on this validation set is 0.10760000348091125
# Epoch 18, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 2.3033313751220703
# The accuracy on this validation set is 0.10760000348091125
# Epoch 19, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 2.3033337593078613
# The accuracy on this validation set is 0.10760000348091125
# Epoch 20, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 2.303335428237915
# The accuracy on this validation set is 0.10760000348091125
# Epoch 21, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 2.3033361434936523
# The accuracy on this validation set is 0.10760000348091125
# Epoch 22, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 2.3033366203308105
# The accuracy on this validation set is 0.10760000348091125
# Epoch 23, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 2.3033366203308105
# The accuracy on this validation set is 0.10760000348091125
# Epoch 24, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 2.3033366203308105
# The accuracy on this validation set is 0.10760000348091125
# Epoch 25, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 2.3033361434936523
# The accuracy on this validation set is 0.10760000348091125
# Epoch 26, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 2.3033359050750732
# The accuracy on this validation set is 0.10760000348091125
# Epoch 27, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 2.303335666656494
# The accuracy on this validation set is 0.10760000348091125
# Epoch 28, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 2.303335666656494
# The accuracy on this validation set is 0.10760000348091125
# Epoch 29, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 2.303335428237915
# The accuracy on this validation set is 0.10760000348091125
# Epoch 30, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 2.3033339977264404
# The accuracy on this validation set is 0.10760000348091125
# Epoch 31, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 2.3033337593078613
# The accuracy on this validation set is 0.10760000348091125
# Epoch 32, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 2.303332805633545
# The accuracy on this validation set is 0.10760000348091125
# Epoch 33, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 2.303332805633545
# The accuracy on this validation set is 0.10760000348091125
# Epoch 34, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 2.3033318519592285
# The accuracy on this validation set is 0.10760000348091125
# Epoch 35, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 2.3033313751220703
# The accuracy on this validation set is 0.10760000348091125
# Epoch 36, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 2.303330898284912
# The accuracy on this validation set is 0.10760000348091125
# Epoch 37, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 2.3033316135406494
# The accuracy on this validation set is 0.10760000348091125
# Epoch 38, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 2.3033316135406494
# The accuracy on this validation set is 0.10760000348091125
# Epoch 39, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 2.303330898284912
# The accuracy on this validation set is 0.10760000348091125
# Epoch 40, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 2.3033313751220703
# The accuracy on this validation set is 0.10760000348091125
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-c232fca844c4> in <module>()
#      12         batch_i = 1
#      13         for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
# ---> 14             train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
#      15         print('Epoch {:>2}, CIFAR-10 Batch| {}:  '.format(epoch + 1, batch_i), end='')
#      16         print_stats(sess, batch_features, batch_labels, cost, accuracy)
#
# <ipython-input-20-ab203e9b5e22> in train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch)
#       9     """
#      10     session.run(optimizer,
# ---> 11                       feed_dict={x: feature_batch,y:label_batch,keep_prob:keep_probability})
#      12     # TODO: Implement Function
#      13     pass
#
# /usr/local/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     776     try:
#     777       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 778                          run_metadata_ptr)
#     779       if run_metadata:
#     780         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     980     if final_fetches or final_targets:
#     981       results = self._do_run(handle, final_targets, final_fetches,
# --> 982                              feed_dict_string, options, run_metadata)
#     983     else:
#     984       results = []
#
# /usr/local/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1030     if handle is None:
#    1031       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1032                            target_list, options, run_metadata)
#    1033     else:
#    1034       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /usr/local/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1037   def _do_call(self, fn, *args):
#    1038     try:
# -> 1039       return fn(*args)
#    1040     except errors.OpError as e:
#    1041       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1019         return tf_session.TF_Run(session, options,
#    1020                                  feed_dict, fetch_list, target_list,
# -> 1021                                  status, run_metadata)
#    1022
#    1023     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 2.453199863433838
# The accuracy on this validation set is 0.16439999639987946
# Epoch  1, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 2.638853073120117
# The accuracy on this validation set is 0.15080000460147858
# Epoch  1, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 1.9114353656768799
# The accuracy on this validation set is 0.24379999935626984
# Epoch  1, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 2.261673927307129
# The accuracy on this validation set is 0.23980000615119934
# Epoch  1, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 1.9119268655776978
# The accuracy on this validation set is 0.2766000032424927
# Epoch  2, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 2.275423288345337
# The accuracy on this validation set is 0.2955999970436096
# Epoch  2, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 2.2212085723876953
# The accuracy on this validation set is 0.30820000171661377
# Epoch  2, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 1.6745895147323608
# The accuracy on this validation set is 0.30160000920295715
# Epoch  2, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 2.026337146759033
# The accuracy on this validation set is 0.352400004863739
# Epoch  2, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 1.844427227973938
# The accuracy on this validation set is 0.33379998803138733
# Epoch  3, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 1.9930870532989502
# The accuracy on this validation set is 0.35740000009536743
# Epoch  3, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 1.7012765407562256
# The accuracy on this validation set is 0.36579999327659607
# Epoch  3, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 1.422774076461792
# The accuracy on this validation set is 0.34619998931884766
# Epoch  3, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 1.746633768081665
# The accuracy on this validation set is 0.384799987077713
# Epoch  3, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 1.8208036422729492
# The accuracy on this validation set is 0.34860000014305115
# Epoch  4, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 1.6656330823898315
# The accuracy on this validation set is 0.3601999878883362
# Epoch  4, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 1.5246506929397583
# The accuracy on this validation set is 0.4291999936103821
# Epoch  4, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 1.2205331325531006
# The accuracy on this validation set is 0.42179998755455017
# Epoch  4, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 1.627436637878418
# The accuracy on this validation set is 0.40939998626708984
# Epoch  4, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 1.6143486499786377
# The accuracy on this validation set is 0.4052000045776367
# Epoch  5, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 1.9625245332717896
# The accuracy on this validation set is 0.382999986410141
# Epoch  5, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 1.4670143127441406
# The accuracy on this validation set is 0.41600000858306885
# Epoch  5, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 1.0946487188339233
# The accuracy on this validation set is 0.4196000099182129
# Epoch  5, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 1.5565310716629028
# The accuracy on this validation set is 0.44020000100135803
# Epoch  5, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 1.675330638885498
# The accuracy on this validation set is 0.454800009727478
# Epoch  6, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 1.7714143991470337
# The accuracy on this validation set is 0.4043999910354614
# Epoch  6, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 1.258150339126587
# The accuracy on this validation set is 0.44940000772476196
# Epoch  6, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 1.2757216691970825
# The accuracy on this validation set is 0.4302000105381012
# Epoch  6, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 1.473144292831421
# The accuracy on this validation set is 0.4607999920845032
# Epoch  6, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 1.9004172086715698
# The accuracy on this validation set is 0.44020000100135803
# Epoch  7, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 1.4192559719085693
# The accuracy on this validation set is 0.3928000032901764
# Epoch  7, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 1.1204975843429565
# The accuracy on this validation set is 0.459199994802475
# Epoch  7, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 1.1402621269226074
# The accuracy on this validation set is 0.4814000129699707
# Epoch  7, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 1.4089574813842773
# The accuracy on this validation set is 0.483599990606308
# Epoch  7, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 1.6496628522872925
# The accuracy on this validation set is 0.487199991941452
# Epoch  8, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 1.4067535400390625
# The accuracy on this validation set is 0.40700000524520874
# Epoch  8, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 1.0939924716949463
# The accuracy on this validation set is 0.4787999987602234
# Epoch  8, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 1.06671941280365
# The accuracy on this validation set is 0.4781999886035919
# Epoch  8, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 1.3763830661773682
# The accuracy on this validation set is 0.48019999265670776
# Epoch  8, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 1.768040657043457
# The accuracy on this validation set is 0.47600001096725464
# Epoch  9, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 1.375558853149414
# The accuracy on this validation set is 0.4747999906539917
# Epoch  9, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 1.1642320156097412
# The accuracy on this validation set is 0.4772000014781952
# Epoch  9, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 1.1924002170562744
# The accuracy on this validation set is 0.4867999851703644
# Epoch  9, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 1.33268141746521
# The accuracy on this validation set is 0.5052000284194946
# Epoch  9, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 1.7628055810928345
# The accuracy on this validation set is 0.49140000343322754
# Epoch 10, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 1.3334048986434937
# The accuracy on this validation set is 0.48559999465942383
# Epoch 10, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 1.1619348526000977
# The accuracy on this validation set is 0.49540001153945923
# Epoch 10, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 1.1520318984985352
# The accuracy on this validation set is 0.5031999945640564
# Epoch 10, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 1.1966803073883057
# The accuracy on this validation set is 0.490200012922287
# Epoch 10, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 1.6929740905761719
# The accuracy on this validation set is 0.4875999987125397
# Epoch 11, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 1.1703764200210571
# The accuracy on this validation set is 0.46160000562667847
# Epoch 11, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 1.0066150426864624
# The accuracy on this validation set is 0.4968000054359436
# Epoch 11, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.960590124130249
# The accuracy on this validation set is 0.5130000114440918
# Epoch 11, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 1.2328763008117676
# The accuracy on this validation set is 0.5134000182151794
# Epoch 11, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 1.3482136726379395
# The accuracy on this validation set is 0.5257999897003174
# Epoch 12, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 1.2256054878234863
# The accuracy on this validation set is 0.4893999993801117
# Epoch 12, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.9797601699829102
# The accuracy on this validation set is 0.5224000215530396
# Epoch 12, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 1.0981874465942383
# The accuracy on this validation set is 0.5041999816894531
# Epoch 12, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 1.0935462713241577
# The accuracy on this validation set is 0.5234000086784363
# Epoch 12, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 1.4215571880340576
# The accuracy on this validation set is 0.5217999815940857
# Epoch 13, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 1.169219970703125
# The accuracy on this validation set is 0.5105999708175659
# Epoch 13, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.979118824005127
# The accuracy on this validation set is 0.5108000040054321
# Epoch 13, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 1.0955557823181152
# The accuracy on this validation set is 0.5153999924659729
# Epoch 13, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 1.1690185070037842
# The accuracy on this validation set is 0.5206000208854675
# Epoch 13, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 1.3443539142608643
# The accuracy on this validation set is 0.5311999917030334
# Epoch 14, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 1.201526165008545
# The accuracy on this validation set is 0.4943999946117401
# Epoch 14, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.962306022644043
# The accuracy on this validation set is 0.5116000175476074
# Epoch 14, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 1.0294995307922363
# The accuracy on this validation set is 0.5296000242233276
# Epoch 14, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 1.044201374053955
# The accuracy on this validation set is 0.5401999950408936
# Epoch 14, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 1.2183990478515625
# The accuracy on this validation set is 0.5479999780654907
# Epoch 15, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 1.2990376949310303
# The accuracy on this validation set is 0.49219998717308044
# Epoch 15, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.8688122630119324
# The accuracy on this validation set is 0.5329999923706055
# Epoch 15, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.9950689077377319
# The accuracy on this validation set is 0.5248000025749207
# Epoch 15, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 1.0998214483261108
# The accuracy on this validation set is 0.5284000039100647
# Epoch 15, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 1.2963321208953857
# The accuracy on this validation set is 0.5443999767303467
# Epoch 16, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 1.1342058181762695
# The accuracy on this validation set is 0.5054000020027161
# Epoch 16, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.8281108140945435
# The accuracy on this validation set is 0.545199990272522
# Epoch 16, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.9787569642066956
# The accuracy on this validation set is 0.5479999780654907
# Epoch 16, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 1.0928034782409668
# The accuracy on this validation set is 0.5460000038146973
# Epoch 16, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 1.3687678575515747
# The accuracy on this validation set is 0.5651999711990356
# Epoch 17, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 1.2535085678100586
# The accuracy on this validation set is 0.5400000214576721
# Epoch 17, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.8004143834114075
# The accuracy on this validation set is 0.5473999977111816
# Epoch 17, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.9395370483398438
# The accuracy on this validation set is 0.5478000044822693
# Epoch 17, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.9466917514801025
# The accuracy on this validation set is 0.5583999752998352
# Epoch 17, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 1.2009289264678955
# The accuracy on this validation set is 0.5691999793052673
# Epoch 18, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 1.306593418121338
# The accuracy on this validation set is 0.5180000066757202
# Epoch 18, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.6970497965812683
# The accuracy on this validation set is 0.5580000281333923
# Epoch 18, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 1.037082314491272
# The accuracy on this validation set is 0.5522000193595886
# Epoch 18, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 1.0330557823181152
# The accuracy on this validation set is 0.5609999895095825
# Epoch 18, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 1.2343145608901978
# The accuracy on this validation set is 0.5667999982833862
# Epoch 19, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 1.1930302381515503
# The accuracy on this validation set is 0.5600000023841858
# Epoch 19, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.7978783845901489
# The accuracy on this validation set is 0.5527999997138977
# Epoch 19, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.9524657130241394
# The accuracy on this validation set is 0.5637999773025513
# Epoch 19, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.9571247100830078
# The accuracy on this validation set is 0.574999988079071
# Epoch 19, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 1.2304763793945312
# The accuracy on this validation set is 0.5645999908447266
# Epoch 20, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 1.190311074256897
# The accuracy on this validation set is 0.5325999855995178
# Epoch 20, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.781347393989563
# The accuracy on this validation set is 0.5573999881744385
# Epoch 20, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.9064612984657288
# The accuracy on this validation set is 0.5708000063896179
# Epoch 20, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.9394135475158691
# The accuracy on this validation set is 0.5691999793052673
# Epoch 20, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 1.1334071159362793
# The accuracy on this validation set is 0.5540000200271606
# Epoch 21, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.993438720703125
# The accuracy on this validation set is 0.5325999855995178
# Epoch 21, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.7408589124679565
# The accuracy on this validation set is 0.5479999780654907
# Epoch 21, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.8406417965888977
# The accuracy on this validation set is 0.5547999739646912
# Epoch 21, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.8905659317970276
# The accuracy on this validation set is 0.5442000031471252
# Epoch 21, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 1.047485589981079
# The accuracy on this validation set is 0.569599986076355
# Epoch 22, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 1.1362318992614746
# The accuracy on this validation set is 0.5360000133514404
# Epoch 22, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.7009391188621521
# The accuracy on this validation set is 0.5685999989509583
# Epoch 22, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.8276263475418091
# The accuracy on this validation set is 0.5709999799728394
# Epoch 22, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.9532750844955444
# The accuracy on this validation set is 0.5763999819755554
# Epoch 22, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.9935203194618225
# The accuracy on this validation set is 0.5681999921798706
# Epoch 23, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 1.1565042734146118
# The accuracy on this validation set is 0.5389999747276306
# Epoch 23, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.6247429251670837
# The accuracy on this validation set is 0.5447999835014343
# Epoch 23, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.6940295100212097
# The accuracy on this validation set is 0.5723999738693237
# Epoch 23, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.9239000082015991
# The accuracy on this validation set is 0.5767999887466431
# Epoch 23, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.9924277067184448
# The accuracy on this validation set is 0.5687999725341797
# Epoch 24, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 1.1510365009307861
# The accuracy on this validation set is 0.5627999901771545
# Epoch 24, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.6693099141120911
# The accuracy on this validation set is 0.5482000112533569
# Epoch 24, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.6992031931877136
# The accuracy on this validation set is 0.5636000037193298
# Epoch 24, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.8668006062507629
# The accuracy on this validation set is 0.5627999901771545
# Epoch 24, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 1.102510929107666
# The accuracy on this validation set is 0.5740000009536743
# Epoch 25, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 1.144197702407837
# The accuracy on this validation set is 0.5645999908447266
# Epoch 25, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.7172625064849854
# The accuracy on this validation set is 0.5509999990463257
# Epoch 25, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.6331499814987183
# The accuracy on this validation set is 0.5803999900817871
# Epoch 25, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.8590396642684937
# The accuracy on this validation set is 0.5824000239372253
# Epoch 25, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 1.049092411994934
# The accuracy on this validation set is 0.5658000111579895
# Epoch 26, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 1.1371960639953613
# The accuracy on this validation set is 0.5583999752998352
# Epoch 26, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.6999322175979614
# The accuracy on this validation set is 0.5817999839782715
# Epoch 26, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.8110629320144653
# The accuracy on this validation set is 0.5745999813079834
# Epoch 26, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.8972665667533875
# The accuracy on this validation set is 0.5763999819755554
# Epoch 26, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 1.0289907455444336
# The accuracy on this validation set is 0.5785999894142151
# Epoch 27, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 1.1088292598724365
# The accuracy on this validation set is 0.5774000287055969
# Epoch 27, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.6576577425003052
# The accuracy on this validation set is 0.573199987411499
# Epoch 27, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.789342999458313
# The accuracy on this validation set is 0.5748000144958496
# Epoch 27, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.894676148891449
# The accuracy on this validation set is 0.5875999927520752
# Epoch 27, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.9666603803634644
# The accuracy on this validation set is 0.5831999778747559
# Epoch 28, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 1.1425552368164062
# The accuracy on this validation set is 0.5644000172615051
# Epoch 28, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.6859081983566284
# The accuracy on this validation set is 0.5856000185012817
# Epoch 28, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.5872982740402222
# The accuracy on this validation set is 0.5835999846458435
# Epoch 28, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.8523424863815308
# The accuracy on this validation set is 0.5658000111579895
# Epoch 28, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.9189932346343994
# The accuracy on this validation set is 0.5929999947547913
# Epoch 29, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 1.06489896774292
# The accuracy on this validation set is 0.5863999724388123
# Epoch 29, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.5370293259620667
# The accuracy on this validation set is 0.5756000280380249
# Epoch 29, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.5959904789924622
# The accuracy on this validation set is 0.5834000110626221
# Epoch 29, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.888120710849762
# The accuracy on this validation set is 0.5856000185012817
# Epoch 29, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.8412920236587524
# The accuracy on this validation set is 0.5734000205993652
# Epoch 30, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 1.0026769638061523
# The accuracy on this validation set is 0.5788000226020813
# Epoch 30, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.6107113361358643
# The accuracy on this validation set is 0.5703999996185303
# Epoch 30, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.5868692398071289
# The accuracy on this validation set is 0.5953999757766724
# Epoch 30, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.7605140209197998
# The accuracy on this validation set is 0.5825999975204468
# Epoch 30, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.9525203108787537
# The accuracy on this validation set is 0.5813999772071838
# Epoch 31, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 1.1027185916900635
# The accuracy on this validation set is 0.5705999732017517
# Epoch 31, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.5904603004455566
# The accuracy on this validation set is 0.5863999724388123
# Epoch 31, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.6395303010940552
# The accuracy on this validation set is 0.5996000170707703
# Epoch 31, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.7647687196731567
# The accuracy on this validation set is 0.5978000164031982
# Epoch 31, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 1.04658842086792
# The accuracy on this validation set is 0.5740000009536743
# Epoch 32, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.9107232093811035
# The accuracy on this validation set is 0.5871999859809875
# Epoch 32, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.6344801783561707
# The accuracy on this validation set is 0.5691999793052673
# Epoch 32, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.5367425680160522
# The accuracy on this validation set is 0.5965999960899353
# Epoch 32, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.7886205911636353
# The accuracy on this validation set is 0.6025999784469604
# Epoch 32, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.7564167976379395
# The accuracy on this validation set is 0.5879999995231628
# Epoch 33, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 1.0243504047393799
# The accuracy on this validation set is 0.5708000063896179
# Epoch 33, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.5296746492385864
# The accuracy on this validation set is 0.5830000042915344
# Epoch 33, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.565844714641571
# The accuracy on this validation set is 0.5996000170707703
# Epoch 33, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.7610752582550049
# The accuracy on this validation set is 0.5961999893188477
# Epoch 33, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 1.051806926727295
# The accuracy on this validation set is 0.5770000219345093
# Epoch 34, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.8946933150291443
# The accuracy on this validation set is 0.5807999968528748
# Epoch 34, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.6759008169174194
# The accuracy on this validation set is 0.550599992275238
# Epoch 34, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.5075589418411255
# The accuracy on this validation set is 0.5956000089645386
# Epoch 34, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.7732575535774231
# The accuracy on this validation set is 0.5874000191688538
# Epoch 34, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.9123700857162476
# The accuracy on this validation set is 0.590399980545044
# Epoch 35, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.9289815425872803
# The accuracy on this validation set is 0.5684000253677368
# Epoch 35, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.6160719394683838
# The accuracy on this validation set is 0.579200029373169
# Epoch 35, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.5889260172843933
# The accuracy on this validation set is 0.5906000137329102
# Epoch 35, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.7168561220169067
# The accuracy on this validation set is 0.5853999853134155
# Epoch 35, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.7839279174804688
# The accuracy on this validation set is 0.5911999940872192
# Epoch 36, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 1.107748031616211
# The accuracy on this validation set is 0.550599992275238
# Epoch 36, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.5462784171104431
# The accuracy on this validation set is 0.5490000247955322
# Epoch 36, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.6689224243164062
# The accuracy on this validation set is 0.5809999704360962
# Epoch 36, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.7615097761154175
# The accuracy on this validation set is 0.5938000082969666
# Epoch 36, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.733185887336731
# The accuracy on this validation set is 0.6025999784469604
# Epoch 37, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.9221289753913879
# The accuracy on this validation set is 0.5838000178337097
# Epoch 37, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.5685739517211914
# The accuracy on this validation set is 0.5658000111579895
# Epoch 37, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.6644291281700134
# The accuracy on this validation set is 0.599399983882904
# Epoch 37, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.7748936414718628
# The accuracy on this validation set is 0.6010000109672546
# Epoch 37, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.8992771506309509
# The accuracy on this validation set is 0.599399983882904
# Epoch 38, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.910172164440155
# The accuracy on this validation set is 0.5781999826431274
# Epoch 38, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.5430816411972046
# The accuracy on this validation set is 0.5720000267028809
# Epoch 38, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.5228980183601379
# The accuracy on this validation set is 0.6179999709129333
# Epoch 38, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.7866447567939758
# The accuracy on this validation set is 0.6014000177383423
# Epoch 38, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.834136962890625
# The accuracy on this validation set is 0.6218000054359436
# Epoch 39, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.9349793791770935
# The accuracy on this validation set is 0.5925999879837036
# Epoch 39, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.5427611470222473
# The accuracy on this validation set is 0.5708000063896179
# Epoch 39, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.39485687017440796
# The accuracy on this validation set is 0.6068000197410583
# Epoch 39, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.7253619432449341
# The accuracy on this validation set is 0.6043999791145325
# Epoch 39, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.8072611093521118
# The accuracy on this validation set is 0.6000000238418579
# Epoch 40, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.7946882247924805
# The accuracy on this validation set is 0.592199981212616
# Epoch 40, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.5461015701293945
# The accuracy on this validation set is 0.574400007724762
# Epoch 40, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.43133220076560974
# The accuracy on this validation set is 0.5971999764442444
# Epoch 40, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.7928758859634399
# The accuracy on this validation set is 0.5920000076293945
# Epoch 40, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.7281543016433716
# The accuracy on this validation set is 0.6132000088691711
# Epoch 41, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.9164508581161499
# The accuracy on this validation set is 0.5774000287055969
# Epoch 41, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.4956514239311218
# The accuracy on this validation set is 0.5830000042915344
# Epoch 41, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.412750244140625
# The accuracy on this validation set is 0.5938000082969666
# Epoch 41, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.6870865225791931
# The accuracy on this validation set is 0.6055999994277954
# Epoch 41, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.7178668975830078
# The accuracy on this validation set is 0.6060000061988831
# Epoch 42, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.8285007476806641
# The accuracy on this validation set is 0.5789999961853027
# Epoch 42, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.5977969765663147
# The accuracy on this validation set is 0.5758000016212463
# Epoch 42, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.44779279828071594
# The accuracy on this validation set is 0.6050000190734863
# Epoch 42, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.6835172772407532
# The accuracy on this validation set is 0.602400004863739
# Epoch 42, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.7274452447891235
# The accuracy on this validation set is 0.6074000000953674
# Epoch 43, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.8089832067489624
# The accuracy on this validation set is 0.590399980545044
# Epoch 43, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.575053870677948
# The accuracy on this validation set is 0.5576000213623047
# Epoch 43, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.40040940046310425
# The accuracy on this validation set is 0.6083999872207642
# Epoch 43, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.620184063911438
# The accuracy on this validation set is 0.600600004196167
# Epoch 43, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.7072157859802246
# The accuracy on this validation set is 0.6028000116348267
# Epoch 44, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.7783175110816956
# The accuracy on this validation set is 0.5911999940872192
# Epoch 44, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.5264838933944702
# The accuracy on this validation set is 0.569599986076355
# Epoch 44, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.40578746795654297
# The accuracy on this validation set is 0.6069999933242798
# Epoch 44, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.6050707697868347
# The accuracy on this validation set is 0.5925999879837036
# Epoch 44, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.7660620212554932
# The accuracy on this validation set is 0.6128000020980835
# Epoch 45, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.8170579671859741
# The accuracy on this validation set is 0.5952000021934509
# Epoch 45, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.4945725202560425
# The accuracy on this validation set is 0.5756000280380249
# Epoch 45, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.2982029318809509
# The accuracy on this validation set is 0.6025999784469604
# Epoch 45, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.7421056032180786
# The accuracy on this validation set is 0.5938000082969666
# Epoch 45, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.767090916633606
# The accuracy on this validation set is 0.6205999851226807
# Epoch 46, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.6840699911117554
# The accuracy on this validation set is 0.5925999879837036
# Epoch 46, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.5327172875404358
# The accuracy on this validation set is 0.5885999798774719
# Epoch 46, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.38086068630218506
# The accuracy on this validation set is 0.6133999824523926
# Epoch 46, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.7126730680465698
# The accuracy on this validation set is 0.6014000177383423
# Epoch 46, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.8050708770751953
# The accuracy on this validation set is 0.6110000014305115
# Epoch 47, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.6948761343955994
# The accuracy on this validation set is 0.6025999784469604
# Epoch 47, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.4624548554420471
# The accuracy on this validation set is 0.5806000232696533
# Epoch 47, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.39735373854637146
# The accuracy on this validation set is 0.605400025844574
# Epoch 47, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.641708254814148
# The accuracy on this validation set is 0.603600025177002
# Epoch 47, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.8049335479736328
# The accuracy on this validation set is 0.6251999735832214
# Epoch 48, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.6395975947380066
# The accuracy on this validation set is 0.5842000246047974
# Epoch 48, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.43032407760620117
# The accuracy on this validation set is 0.5759999752044678
# Epoch 48, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.40757855772972107
# The accuracy on this validation set is 0.6155999898910522
# Epoch 48, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.5512048602104187
# The accuracy on this validation set is 0.5924000144004822
# Epoch 48, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.6510294675827026
# The accuracy on this validation set is 0.6197999715805054
# Epoch 49, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.7211847305297852
# The accuracy on this validation set is 0.5978000164031982
# Epoch 49, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.47907745838165283
# The accuracy on this validation set is 0.5699999928474426
# Epoch 49, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.3756507635116577
# The accuracy on this validation set is 0.6101999878883362
# Epoch 49, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.6483869552612305
# The accuracy on this validation set is 0.6140000224113464
# Epoch 49, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.8434498310089111
# The accuracy on this validation set is 0.6200000047683716
# Epoch 50, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.7913984656333923
# The accuracy on this validation set is 0.5911999940872192
# Epoch 50, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.3982442021369934
# The accuracy on this validation set is 0.5870000123977661
# Epoch 50, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.36965212225914
# The accuracy on this validation set is 0.6104000210762024
# Epoch 50, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.5433473587036133
# The accuracy on this validation set is 0.6161999702453613
# Epoch 50, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.7047595977783203
# The accuracy on this validation set is 0.602400004863739
# Epoch 51, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.6799124479293823
# The accuracy on this validation set is 0.5956000089645386
# Epoch 51, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.4901464581489563
# The accuracy on this validation set is 0.5960000157356262
# Epoch 51, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.38914018869400024
# The accuracy on this validation set is 0.5914000272750854
# Epoch 51, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.6483466029167175
# The accuracy on this validation set is 0.6050000190734863
# Epoch 51, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.7702705264091492
# The accuracy on this validation set is 0.6155999898910522
# Epoch 52, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.60207200050354
# The accuracy on this validation set is 0.593999981880188
# Epoch 52, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.4538145363330841
# The accuracy on this validation set is 0.599399983882904
# Epoch 52, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.33521711826324463
# The accuracy on this validation set is 0.6064000129699707
# Epoch 52, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.608391523361206
# The accuracy on this validation set is 0.6060000061988831
# Epoch 52, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.6951593160629272
# The accuracy on this validation set is 0.6154000163078308
# Epoch 53, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.47503137588500977
# The accuracy on this validation set is 0.616599977016449
# Epoch 53, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.4010995626449585
# The accuracy on this validation set is 0.6014000177383423
# Epoch 53, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.38016819953918457
# The accuracy on this validation set is 0.6039999723434448
# Epoch 53, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.605648398399353
# The accuracy on this validation set is 0.6159999966621399
# Epoch 53, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.7097752094268799
# The accuracy on this validation set is 0.6236000061035156
# Epoch 54, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.5426086783409119
# The accuracy on this validation set is 0.6082000136375427
# Epoch 54, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.43264931440353394
# The accuracy on this validation set is 0.5911999940872192
# Epoch 54, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.38298115134239197
# The accuracy on this validation set is 0.61080002784729
# Epoch 54, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.6277016997337341
# The accuracy on this validation set is 0.6057999730110168
# Epoch 54, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.6713986396789551
# The accuracy on this validation set is 0.6129999756813049
# Epoch 55, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.5174530744552612
# The accuracy on this validation set is 0.6092000007629395
# Epoch 55, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.4630582332611084
# The accuracy on this validation set is 0.593999981880188
# Epoch 55, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.30971449613571167
# The accuracy on this validation set is 0.6190000176429749
# Epoch 55, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.6102202534675598
# The accuracy on this validation set is 0.6158000230789185
# Epoch 55, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.7033304572105408
# The accuracy on this validation set is 0.6255999803543091
# Epoch 56, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.5710986852645874
# The accuracy on this validation set is 0.6065999865531921
# Epoch 56, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.40844401717185974
# The accuracy on this validation set is 0.5842000246047974
# Epoch 56, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.3324456214904785
# The accuracy on this validation set is 0.6079999804496765
# Epoch 56, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.5282111763954163
# The accuracy on this validation set is 0.59579998254776
# Epoch 56, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.5289441347122192
# The accuracy on this validation set is 0.6191999912261963
# Epoch 57, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.5751632452011108
# The accuracy on this validation set is 0.6200000047683716
# Epoch 57, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.4533165395259857
# The accuracy on this validation set is 0.5920000076293945
# Epoch 57, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.27428528666496277
# The accuracy on this validation set is 0.6083999872207642
# Epoch 57, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.564223051071167
# The accuracy on this validation set is 0.6205999851226807
# Epoch 57, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.5659027695655823
# The accuracy on this validation set is 0.6338000297546387
# Epoch 58, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.4749535918235779
# The accuracy on this validation set is 0.6087999939918518
# Epoch 58, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.45544788241386414
# The accuracy on this validation set is 0.5812000036239624
# Epoch 58, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.22093069553375244
# The accuracy on this validation set is 0.625
# Epoch 58, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.5682790279388428
# The accuracy on this validation set is 0.6179999709129333
# Epoch 58, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.6433599591255188
# The accuracy on this validation set is 0.6218000054359436
# Epoch 59, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.5367165207862854
# The accuracy on this validation set is 0.602400004863739
# Epoch 59, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.37905174493789673
# The accuracy on this validation set is 0.6032000184059143
# Epoch 59, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.3334464132785797
# The accuracy on this validation set is 0.5946000218391418
# Epoch 59, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.5786091089248657
# The accuracy on this validation set is 0.6179999709129333
# Epoch 59, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.6315880417823792
# The accuracy on this validation set is 0.6237999796867371
# Epoch 60, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.4802206754684448
# The accuracy on this validation set is 0.6123999953269958
# Epoch 60, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.4346471428871155
# The accuracy on this validation set is 0.5827999711036682
# Epoch 60, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.2858111560344696
# The accuracy on this validation set is 0.6068000197410583
# Epoch 60, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.551037073135376
# The accuracy on this validation set is 0.6168000102043152
# Epoch 60, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.6176857948303223
# The accuracy on this validation set is 0.6111999750137329
# Epoch 61, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.5297865271568298
# The accuracy on this validation set is 0.6039999723434448
# Epoch 61, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.3332282602787018
# The accuracy on this validation set is 0.5774000287055969
# Epoch 61, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.30771929025650024
# The accuracy on this validation set is 0.6101999878883362
# Epoch 61, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.5812946557998657
# The accuracy on this validation set is 0.6146000027656555
# Epoch 61, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.5927518010139465
# The accuracy on this validation set is 0.6126000285148621
# Epoch 62, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.5991265773773193
# The accuracy on this validation set is 0.6074000000953674
# Epoch 62, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.41189390420913696
# The accuracy on this validation set is 0.5827999711036682
# Epoch 62, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.36437731981277466
# The accuracy on this validation set is 0.6082000136375427
# Epoch 62, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.4868621826171875
# The accuracy on this validation set is 0.6204000115394592
# Epoch 62, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.6278089284896851
# The accuracy on this validation set is 0.6233999729156494
# Epoch 63, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.48859524726867676
# The accuracy on this validation set is 0.6019999980926514
# Epoch 63, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.375367671251297
# The accuracy on this validation set is 0.598800003528595
# Epoch 63, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.3235427439212799
# The accuracy on this validation set is 0.5983999967575073
# Epoch 63, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.5254988074302673
# The accuracy on this validation set is 0.6122000217437744
# Epoch 63, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.556381106376648
# The accuracy on this validation set is 0.5989999771118164
# Epoch 64, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.41356992721557617
# The accuracy on this validation set is 0.614799976348877
# Epoch 64, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.29315701127052307
# The accuracy on this validation set is 0.6000000238418579
# Epoch 64, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.3431100845336914
# The accuracy on this validation set is 0.6276000142097473
# Epoch 64, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.5287224650382996
# The accuracy on this validation set is 0.6078000068664551
# Epoch 64, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.717546820640564
# The accuracy on this validation set is 0.6187999844551086
# Epoch 65, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.4903045892715454
# The accuracy on this validation set is 0.6141999959945679
# Epoch 65, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.3825434446334839
# The accuracy on this validation set is 0.5875999927520752
# Epoch 65, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.23126380145549774
# The accuracy on this validation set is 0.6168000102043152
# Epoch 65, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.585241436958313
# The accuracy on this validation set is 0.6151999831199646
# Epoch 65, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.606010913848877
# The accuracy on this validation set is 0.6164000034332275
# Epoch 66, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.511619508266449
# The accuracy on this validation set is 0.6227999925613403
# Epoch 66, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.3706747591495514
# The accuracy on this validation set is 0.5784000158309937
# Epoch 66, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.20033282041549683
# The accuracy on this validation set is 0.6140000224113464
# Epoch 66, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.49352502822875977
# The accuracy on this validation set is 0.6226000189781189
# Epoch 66, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.6281154751777649
# The accuracy on this validation set is 0.6177999973297119
# Epoch 67, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.3990166187286377
# The accuracy on this validation set is 0.609000027179718
# Epoch 67, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.3381710648536682
# The accuracy on this validation set is 0.5929999947547913
# Epoch 67, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.35708868503570557
# The accuracy on this validation set is 0.607200026512146
# Epoch 67, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.5119132995605469
# The accuracy on this validation set is 0.6164000034332275
# Epoch 67, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.5784807801246643
# The accuracy on this validation set is 0.6194000244140625
# Epoch 68, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.3646708130836487
# The accuracy on this validation set is 0.6018000245094299
# Epoch 68, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.3560168743133545
# The accuracy on this validation set is 0.5861999988555908
# Epoch 68, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.21632179617881775
# The accuracy on this validation set is 0.6104000210762024
# Epoch 68, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.45667940378189087
# The accuracy on this validation set is 0.6105999946594238
# Epoch 68, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.544845461845398
# The accuracy on this validation set is 0.623199999332428
# Epoch 69, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.4983300268650055
# ...
# Epoch 78, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.22801175713539124
# The accuracy on this validation set is 0.6093999743461609
# Epoch 78, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.5154380202293396
# The accuracy on this validation set is 0.6218000054359436
# Epoch 78, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.5705551505088806
# The accuracy on this validation set is 0.6179999709129333
# Epoch 79, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.3454650044441223
# The accuracy on this validation set is 0.6079999804496765
# Epoch 79, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.36444729566574097
# The accuracy on this validation set is 0.5917999744415283
# Epoch 79, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.31495201587677
# The accuracy on this validation set is 0.5920000076293945
# Epoch 79, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.4484075903892517
# The accuracy on this validation set is 0.6158000230789185
# Epoch 79, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.49964237213134766
# The accuracy on this validation set is 0.6177999973297119
# Epoch 80, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.37902748584747314
# The accuracy on this validation set is 0.6159999966621399
# Epoch 80, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.4159102439880371
# The accuracy on this validation set is 0.6043999791145325
# Epoch 80, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.29548028111457825
# The accuracy on this validation set is 0.5965999960899353
# Epoch 80, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.4615411162376404
# The accuracy on this validation set is 0.6158000230789185
# Epoch 80, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.5523802042007446
# The accuracy on this validation set is 0.6187999844551086
# Epoch 81, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.3713383376598358
# The accuracy on this validation set is 0.6111999750137329
# Epoch 81, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.36108943819999695
# The accuracy on this validation set is 0.5971999764442444
# Epoch 81, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.22637493908405304
# The accuracy on this validation set is 0.6114000082015991
# Epoch 81, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.47651320695877075
# The accuracy on this validation set is 0.6111999750137329
# Epoch 81, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.5590192675590515
# The accuracy on this validation set is 0.6114000082015991
# Epoch 82, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.3126888871192932
# The accuracy on this validation set is 0.6119999885559082
# Epoch 82, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.3212421238422394
# The accuracy on this validation set is 0.5950000286102295
# Epoch 82, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.2077436000108719
# The accuracy on this validation set is 0.6064000129699707
# Epoch 82, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.43304890394210815
# The accuracy on this validation set is 0.6150000095367432
# Epoch 82, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.5319913029670715
# The accuracy on this validation set is 0.6161999702453613
# Epoch 83, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.32278141379356384
# The accuracy on this validation set is 0.5965999960899353
# Epoch 83, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.31794923543930054
# The accuracy on this validation set is 0.5860000252723694
# Epoch 83, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.2708148658275604
# The accuracy on this validation set is 0.5881999731063843
# Epoch 83, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.5285671949386597
# The accuracy on this validation set is 0.6182000041007996
# Epoch 83, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.3859654366970062
# The accuracy on this validation set is 0.6146000027656555
# Epoch 84, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.2831464409828186
# The accuracy on this validation set is 0.5965999960899353
# Epoch 84, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.35599830746650696
# The accuracy on this validation set is 0.5979999899864197
# Epoch 84, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.17271876335144043
# The accuracy on this validation set is 0.6151999831199646
# Epoch 84, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.5214866399765015
# The accuracy on this validation set is 0.5943999886512756
# Epoch 84, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.458026647567749
# The accuracy on this validation set is 0.6086000204086304
# Epoch 85, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.29693102836608887
# The accuracy on this validation set is 0.6068000197410583
# Epoch 85, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.5071070790290833
# The accuracy on this validation set is 0.6075999736785889
# Epoch 85, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.22910645604133606
# The accuracy on this validation set is 0.5960000157356262
# Epoch 85, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.4558872580528259
# The accuracy on this validation set is 0.6051999926567078
# Epoch 85, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.38824009895324707
# The accuracy on this validation set is 0.61080002784729
# Epoch 86, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.2924705445766449
# The accuracy on this validation set is 0.6032000184059143
# Epoch 86, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.33150628209114075
# The accuracy on this validation set is 0.5809999704360962
# Epoch 86, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.24723106622695923
# The accuracy on this validation set is 0.5885999798774719
# Epoch 86, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.4681907594203949
# The accuracy on this validation set is 0.609000027179718
# Epoch 86, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.4904244542121887
# The accuracy on this validation set is 0.6075999736785889
# Epoch 87, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.252188116312027
# The accuracy on this validation set is 0.6151999831199646
# Epoch 87, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.3322280943393707
# The accuracy on this validation set is 0.6028000116348267
# Epoch 87, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.18873867392539978
# The accuracy on this validation set is 0.6061999797821045
# Epoch 87, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.44237881898880005
# The accuracy on this validation set is 0.6032000184059143
# Epoch 87, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.48766547441482544
# The accuracy on this validation set is 0.6115999817848206
# Epoch 88, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.3319860100746155
# The accuracy on this validation set is 0.6155999898910522
# Epoch 88, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.3241434395313263
# The accuracy on this validation set is 0.5867999792098999
# Epoch 88, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.2420995533466339
# The accuracy on this validation set is 0.6021999716758728
# Epoch 88, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.4296063780784607
# The accuracy on this validation set is 0.6086000204086304
# Epoch 88, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.44216111302375793
# The accuracy on this validation set is 0.6101999878883362
# Epoch 89, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.2710060179233551
# The accuracy on this validation set is 0.6001999974250793
# Epoch 89, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.3097875118255615
# The accuracy on this validation set is 0.6096000075340271
# Epoch 89, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.22158779203891754
# The accuracy on this validation set is 0.6096000075340271
# Epoch 89, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.45120611786842346
# The accuracy on this validation set is 0.6126000285148621
# Epoch 89, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.4215976595878601
# The accuracy on this validation set is 0.6033999919891357
# Epoch 90, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.21723705530166626
# The accuracy on this validation set is 0.6051999926567078
# Epoch 90, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.34099408984184265
# The accuracy on this validation set is 0.6014000177383423
# Epoch 90, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.3162894546985626
# The accuracy on this validation set is 0.598800003528595
# Epoch 90, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.42051631212234497
# The accuracy on this validation set is 0.6159999966621399
# Epoch 90, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.40561050176620483
# The accuracy on this validation set is 0.6047999858856201
# Epoch 91, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.33194857835769653
# The accuracy on this validation set is 0.6115999817848206
# Epoch 91, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.3293708264827728
# The accuracy on this validation set is 0.5985999703407288
# Epoch 91, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.23159445822238922
# The accuracy on this validation set is 0.5925999879837036
# Epoch 91, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.4900018572807312
# The accuracy on this validation set is 0.6205999851226807
# Epoch 91, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.32327499985694885
# The accuracy on this validation set is 0.605400025844574
# Epoch 92, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.29420945048332214
# The accuracy on this validation set is 0.6015999913215637
# Epoch 92, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.32672378420829773
# The accuracy on this validation set is 0.6092000007629395
# Epoch 92, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.26077210903167725
# The accuracy on this validation set is 0.5978000164031982
# Epoch 92, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.37030744552612305
# The accuracy on this validation set is 0.6197999715805054
# Epoch 92, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.3654462695121765
# The accuracy on this validation set is 0.6092000007629395
# Epoch 93, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.28485989570617676
# The accuracy on this validation set is 0.5982000231742859
# Epoch 93, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.3239874541759491
# The accuracy on this validation set is 0.5952000021934509
# Epoch 93, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.17724332213401794
# The accuracy on this validation set is 0.602400004863739
# Epoch 93, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.3574655055999756
# The accuracy on this validation set is 0.6061999797821045
# Epoch 93, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.427182137966156
# The accuracy on this validation set is 0.602400004863739
# Epoch 94, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.2717784345149994
# The accuracy on this validation set is 0.6032000184059143
# Epoch 94, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.3392655849456787
# The accuracy on this validation set is 0.5914000272750854
# Epoch 94, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.2047622799873352
# The accuracy on this validation set is 0.6046000123023987
# Epoch 94, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.39460787177085876
# The accuracy on this validation set is 0.6150000095367432
# Epoch 94, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.4777022898197174
# The accuracy on this validation set is 0.6046000123023987
# Epoch 95, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.3097198009490967
# The accuracy on this validation set is 0.592199981212616
# Epoch 95, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.32987868785858154
# The accuracy on this validation set is 0.6114000082015991
# Epoch 95, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.18447110056877136
# The accuracy on this validation set is 0.6047999858856201
# Epoch 95, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.4384530186653137
# The accuracy on this validation set is 0.6047999858856201
# Epoch 95, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.42970749735832214
# The accuracy on this validation set is 0.6069999933242798
# Epoch 96, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.21864686906337738
# The accuracy on this validation set is 0.6104000210762024
# Epoch 96, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.24413751065731049
# The accuracy on this validation set is 0.5956000089645386
# Epoch 96, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.24473920464515686
# The accuracy on this validation set is 0.5965999960899353
# Epoch 96, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.4661908745765686
# The accuracy on this validation set is 0.6179999709129333
# Epoch 96, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.5123998522758484
# The accuracy on this validation set is 0.6119999885559082
# Epoch 97, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.2188883274793625
# The accuracy on this validation set is 0.5938000082969666
# Epoch 97, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.40944012999534607
# The accuracy on this validation set is 0.5899999737739563
# Epoch 97, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.2343369573354721
# The accuracy on this validation set is 0.5952000021934509
# Epoch 97, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.3810191750526428
# The accuracy on this validation set is 0.607200026512146
# Epoch 97, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.43572086095809937
# The accuracy on this validation set is 0.6101999878883362
# Epoch 98, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.23244129121303558
# The accuracy on this validation set is 0.6025999784469604
# Epoch 98, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.3298051357269287
# The accuracy on this validation set is 0.6037999987602234
# Epoch 98, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.22241781651973724
# The accuracy on this validation set is 0.6032000184059143
# Epoch 98, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.45000362396240234
# The accuracy on this validation set is 0.6069999933242798
# Epoch 98, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.3700868487358093
# The accuracy on this validation set is 0.6079999804496765
# Epoch 99, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.20619316399097443
# The accuracy on this validation set is 0.6096000075340271
# Epoch 99, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.3499976694583893
# The accuracy on this validation set is 0.6079999804496765
# Epoch 99, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.1559712290763855
# The accuracy on this validation set is 0.6115999817848206
# Epoch 99, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.3848419785499573
# The accuracy on this validation set is 0.6029999852180481
# Epoch 99, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.39567792415618896
# The accuracy on this validation set is 0.6075999736785889
# Epoch 100, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.24148133397102356
# The accuracy on this validation set is 0.6007999777793884
# Epoch 100, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.42998629808425903
# The accuracy on this validation set is 0.5902000069618225
# Epoch 100, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.20661970973014832
# The accuracy on this validation set is 0.5961999893188477
# Epoch 100, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.39907926321029663
# The accuracy on this validation set is 0.6136000156402588
# Epoch 100, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.351380318403244
# The accuracy on this validation set is 0.6092000007629395

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.6346845047923323

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
