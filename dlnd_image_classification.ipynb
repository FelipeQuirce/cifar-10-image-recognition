# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/input/cifar-10/python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 6
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 6:
# Image - Min Value: 7 Max Value: 249
# Image - Shape: (32, 32, 3)
# Label - Label Id: 2 Name: bird

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    array =  x.flatten();
    norm=np.linalg.norm(array)
    normalized_array = x/norm
    print(normalized_array.shape)
    # TODO: Implement Function
    return normalized_array


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# (790, 32, 32, 3)
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
import sklearn
enc = sklearn.preprocessing.OneHotEncoder(sparse=False)
_,label = helper.load_cfar10_batch(cifar10_dataset_folder_path,1)
labels = np.array(label)
fitted_enc = enc.fit(labels.reshape(-1,1))

def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    
    labels = np.array(x).reshape(-1,1)
    fitted = np.array(enc.transform(labels))
    # TODO: Implement Function
    print(fitted.shape)
    return fitted


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# (917, 10)
# (5, 10)
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)
# Out:
# (9000, 32, 32, 3)
# (9000, 10)
# (9000, 32, 32, 3)
# (9000, 10)
# (9000, 32, 32, 3)
# (9000, 10)
# (9000, 32, 32, 3)
# (9000, 10)
# (9000, 32, 32, 3)
# (9000, 10)
# (5000, 32, 32, 3)
# (5000, 10)
# (10000, 32, 32, 3)
# (10000, 10)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    return  tf.placeholder(dtype=tf.float32, shape=((None,)+image_shape),name='x')



def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return  tf.placeholder(dtype=tf.float32, shape=(None,n_classes),name='y')



def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(dtype=tf.float32,name='keep_prob')


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    
    """
    # TODO: Implement Function


    image_depth = x_tensor.get_shape().as_list()[-1]
    conv2d_filter_shape = list(conv_ksize)+[image_depth,conv_num_outputs]
    conv2d_filter = tf.Variable(tf.truncated_normal(conv2d_filter_shape))
    
    bias = tf.Variable(tf.truncated_normal([conv_num_outputs],stddev=0.1))

    conv2d_strides = [1]+list(conv_strides)+[1]
    padding = "SAME"
    conv2d = tf.nn.conv2d(x_tensor, conv2d_filter, conv2d_strides,padding)
    
    conv2d_bias =tf.nn.bias_add(conv2d ,bias)
    
    conv2d_bias_relu = tf.nn.relu(conv2d_bias)
    
    max_pool_strides = [1]+list(pool_strides)+[1]
    pool_ks = [1]+list(pool_ksize)+[1]
    conv2d_max_pool = tf.nn.max_pool(conv2d_bias_relu,pool_ks,max_pool_strides,padding)
    print(conv2d_max_pool)
    
    
    return conv2d_max_pool 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tensor("MaxPool:0", shape=(?, 4, 4, 10), dtype=float32)
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    print("shape before flatten", x_tensor._shape)
    shape = x_tensor.get_shape().as_list() 
    dim = np.prod(shape[1:])
    flatten = tf.reshape(x_tensor,[-1,dim])
    print(flatten)
    
    
    # TODO: Implement Function
    return flatten


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# shape before flatten (?, 10, 30, 6)
# Tensor("Reshape:0", shape=(?, 1800), dtype=float32)
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    w = tf.Variable(tf.truncated_normal([x_tensor.get_shape().as_list()[-1],num_outputs]))
    b = tf.Variable(tf.zeros([num_outputs]))
    # TODO: Implement Function
    fully_connected = tf.matmul(x_tensor,w)+b
    fully_relu = tf.nn.relu(fully_connected)
    print("FULLY_CONNECTED",fully_relu)
    return fully_relu


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# FULLY_CONNECTED Tensor("Relu_1:0", shape=(?, 40), dtype=float32)
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    w = tf.Variable(tf.truncated_normal([x_tensor.get_shape().as_list()[-1],num_outputs],stddev=0.1))
    b = tf.Variable(tf.zeros([num_outputs]))
    # TODO: Implement Function
    output = tf.matmul(x_tensor,w)+b
    print("OUTPUT",output)
    return output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# OUTPUT Tensor("add_1:0", shape=(?, 40), dtype=float32)
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    print("input shape", x._shape)
    conv2d = conv2d_maxpool(x,16,(6,6),(1,1),(2,2),(2,2))

    conv2d = conv2d_maxpool(conv2d,32,(2,2),(1,1),(2,2),(2,2))

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    flat = flatten(conv2d)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    fully = fully_conn(flat,4096)

    fully = tf.nn.dropout(fully,keep_prob)


    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    
    out = output(fully,10)
    # TODO: return output
    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# input shape (?, 32, 32, 3)
# Tensor("MaxPool:0", shape=(?, 16, 16, 16), dtype=float32)
# Tensor("MaxPool_1:0", shape=(?, 8, 8, 32), dtype=float32)
# shape before flatten (?, 8, 8, 32)
# Tensor("Reshape:0", shape=(?, 2048), dtype=float32)
# FULLY_CONNECTED Tensor("Relu_2:0", shape=(?, 4096), dtype=float32)
# OUTPUT Tensor("add_1:0", shape=(?, 10), dtype=float32)
# input shape (?, 32, 32, 3)
# Tensor("MaxPool_2:0", shape=(?, 16, 16, 16), dtype=float32)
# Tensor("MaxPool_3:0", shape=(?, 8, 8, 32), dtype=float32)
# shape before flatten (?, 8, 8, 32)
# Tensor("Reshape_4:0", shape=(?, 2048), dtype=float32)
# FULLY_CONNECTED Tensor("Relu_5:0", shape=(?, 4096), dtype=float32)
# OUTPUT Tensor("add_3:0", shape=(?, 10), dtype=float32)
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    session.run(optimizer,
                      feed_dict={x: feature_batch,y:label_batch,keep_prob:keep_probability})    
    # TODO: Implement Function
    pass


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    print("accuracy ",)
    # TODO: Implement Function
    
    c = session.run(cost, feed_dict={
        x: feature_batch,
        y: label_batch,
        keep_prob: 1.0
    })
    acc = session.run(accuracy, feed_dict={
        x: valid_features,
        y: valid_labels,
        keep_prob: 1.0
    })
    print ("The cost on train set is {}".format(c))
    print ("The accuracy on this validation set is {}".format(acc))
    pass

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
import math
epochs =100

batch_size = math.ceil( math.pow(2,6))

keep_probability = 0.5

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch| {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 3.979206085205078
# The accuracy on this validation set is 0.10119999945163727
# Epoch  2, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 2.2486019134521484
# The accuracy on this validation set is 0.18939998745918274
# Epoch  3, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 2.0591530799865723
# The accuracy on this validation set is 0.2598000168800354
# Epoch  4, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 1.9919785261154175
# The accuracy on this validation set is 0.2991999685764313
# Epoch  5, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 1.921553134918213
# The accuracy on this validation set is 0.29420000314712524
# Epoch  6, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 1.89255690574646
# The accuracy on this validation set is 0.3086000084877014
# Epoch  7, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 1.827902913093567
# The accuracy on this validation set is 0.31360000371932983
# Epoch  8, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 1.8695461750030518
# The accuracy on this validation set is 0.30219995975494385
# Epoch  9, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 1.7890050411224365
# The accuracy on this validation set is 0.3073999881744385
# Epoch 10, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 1.7299268245697021
# The accuracy on this validation set is 0.3357999920845032
# Epoch 11, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 1.708857774734497
# The accuracy on this validation set is 0.35339999198913574
# Epoch 12, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 1.6685467958450317
# The accuracy on this validation set is 0.36219996213912964
# Epoch 13, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 1.6352379322052002
# The accuracy on this validation set is 0.34439998865127563
# Epoch 14, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 1.5972621440887451
# The accuracy on this validation set is 0.4032000005245209
# Epoch 15, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 1.5041964054107666
# The accuracy on this validation set is 0.38159996271133423
# Epoch 16, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 1.4995086193084717
# The accuracy on this validation set is 0.41919994354248047
# Epoch 17, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 1.4539713859558105
# The accuracy on this validation set is 0.3944000005722046
# Epoch 18, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 1.489820122718811
# The accuracy on this validation set is 0.4177999794483185
# Epoch 19, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 1.4299124479293823
# The accuracy on this validation set is 0.42879998683929443
# Epoch 20, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 1.4561268091201782
# The accuracy on this validation set is 0.45819997787475586
# Epoch 21, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 1.4552299976348877
# The accuracy on this validation set is 0.43699997663497925
# Epoch 22, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 1.465701937675476
# The accuracy on this validation set is 0.4567999839782715
# Epoch 23, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 1.4043108224868774
# The accuracy on this validation set is 0.44519996643066406
# Epoch 24, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 1.3852291107177734
# The accuracy on this validation set is 0.4553999602794647
# Epoch 25, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 1.3188726902008057
# The accuracy on this validation set is 0.454399973154068
# Epoch 26, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 1.3068733215332031
# The accuracy on this validation set is 0.4525999426841736
# Epoch 27, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 1.3052799701690674
# The accuracy on this validation set is 0.47179996967315674
# Epoch 28, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 1.218747615814209
# The accuracy on this validation set is 0.46619996428489685
# Epoch 29, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 1.2422091960906982
# The accuracy on this validation set is 0.4635999798774719
# Epoch 30, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 1.2600489854812622
# The accuracy on this validation set is 0.42399996519088745
# Epoch 31, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 1.1833919286727905
# The accuracy on this validation set is 0.4546000063419342
# Epoch 32, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 1.147796630859375
# The accuracy on this validation set is 0.4359999895095825
# Epoch 33, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 1.1973254680633545
# The accuracy on this validation set is 0.42159998416900635
# Epoch 34, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 1.1964751482009888
# The accuracy on this validation set is 0.4367999732494354
# Epoch 35, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 1.0734485387802124
# The accuracy on this validation set is 0.42739999294281006
# Epoch 36, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 1.1323621273040771
# The accuracy on this validation set is 0.46359995007514954
# Epoch 37, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 1.199001669883728
# The accuracy on this validation set is 0.45479997992515564
# Epoch 38, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 1.1271445751190186
# The accuracy on this validation set is 0.44599995017051697
# Epoch 39, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 1.077605128288269
# The accuracy on this validation set is 0.4359999895095825
# Epoch 40, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 1.0216143131256104
# The accuracy on this validation set is 0.44759994745254517
# Epoch 41, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 1.0159237384796143
# The accuracy on this validation set is 0.4487999677658081
# Epoch 42, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.9982132911682129
# The accuracy on this validation set is 0.45719999074935913
# Epoch 43, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 1.0554609298706055
# The accuracy on this validation set is 0.4437999725341797
# Epoch 44, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 1.1164501905441284
# The accuracy on this validation set is 0.44339996576309204
# Epoch 45, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 1.018453598022461
# The accuracy on this validation set is 0.42640000581741333
# Epoch 46, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.8674737215042114
# The accuracy on this validation set is 0.45319998264312744
# Epoch 47, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.8036993741989136
# The accuracy on this validation set is 0.44339999556541443
# Epoch 48, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.8065304160118103
# The accuracy on this validation set is 0.45159995555877686
# Epoch 49, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.7437742948532104
# The accuracy on this validation set is 0.4469999372959137
# Epoch 50, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.7540809512138367
# The accuracy on this validation set is 0.4625999629497528
# Epoch 51, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.7715001106262207
# The accuracy on this validation set is 0.4833999574184418
# Epoch 52, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.776769757270813
# The accuracy on this validation set is 0.4795999825000763
# Epoch 53, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.707202672958374
# The accuracy on this validation set is 0.4867999851703644
# Epoch 54, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.6989977955818176
# The accuracy on this validation set is 0.48259997367858887
# Epoch 55, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.6565729379653931
# The accuracy on this validation set is 0.47519996762275696
# Epoch 56, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.6420167684555054
# The accuracy on this validation set is 0.48619991540908813
# Epoch 57, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.5949465036392212
# The accuracy on this validation set is 0.4917999505996704
# Epoch 58, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.6247573494911194
# The accuracy on this validation set is 0.48559996485710144
# Epoch 59, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.5912761688232422
# The accuracy on this validation set is 0.4731999933719635
# Epoch 60, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.560894787311554
# The accuracy on this validation set is 0.4551999568939209
# Epoch 61, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.633922815322876
# The accuracy on this validation set is 0.45579996705055237
# Epoch 62, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.6126530766487122
# The accuracy on this validation set is 0.4641999304294586
# Epoch 63, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.5288969278335571
# The accuracy on this validation set is 0.47339996695518494
# Epoch 64, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.5761137008666992
# The accuracy on this validation set is 0.4667999744415283
# Epoch 65, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.6158862709999084
# The accuracy on this validation set is 0.46560001373291016
# Epoch 66, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.5489554405212402
# The accuracy on this validation set is 0.47519993782043457
# Epoch 67, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.5042114853858948
# The accuracy on this validation set is 0.4715999662876129
# Epoch 68, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.48432421684265137
# The accuracy on this validation set is 0.4643999934196472
# Epoch 69, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.5284491777420044
# The accuracy on this validation set is 0.47259998321533203
# Epoch 70, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.542202353477478
# The accuracy on this validation set is 0.4517999291419983
# Epoch 71, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.4739592969417572
# The accuracy on this validation set is 0.45879998803138733
# Epoch 72, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.452293336391449
# The accuracy on this validation set is 0.46539995074272156
# Epoch 73, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.41348162293434143
# The accuracy on this validation set is 0.4719999432563782
# Epoch 74, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.3663804233074188
# The accuracy on this validation set is 0.4763999581336975
# Epoch 75, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.320468932390213
# The accuracy on this validation set is 0.4861999452114105
# Epoch 76, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.35022830963134766
# The accuracy on this validation set is 0.47839996218681335
# Epoch 77, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.3330256938934326
# The accuracy on this validation set is 0.48159995675086975
# Epoch 78, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.29014188051223755
# The accuracy on this validation set is 0.47839999198913574
# Epoch 79, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.2606055438518524
# The accuracy on this validation set is 0.4625999927520752
# Epoch 80, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.26579412817955017
# The accuracy on this validation set is 0.4859999418258667
# Epoch 81, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.2810128629207611
# The accuracy on this validation set is 0.4975999593734741
# Epoch 82, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.2482685148715973
# The accuracy on this validation set is 0.4825999438762665
# Epoch 83, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.2477593868970871
# The accuracy on this validation set is 0.4885999858379364
# Epoch 84, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.27246934175491333
# The accuracy on this validation set is 0.4843999743461609
# Epoch 85, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.23287826776504517
# The accuracy on this validation set is 0.4909999668598175
# Epoch 86, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.2639045715332031
# The accuracy on this validation set is 0.5077999830245972
# Epoch 87, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.29432669281959534
# The accuracy on this validation set is 0.49679994583129883
# Epoch 88, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.2764286696910858
# The accuracy on this validation set is 0.4991999864578247
# Epoch 89, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.28915536403656006
# The accuracy on this validation set is 0.506399929523468
# Epoch 90, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.21869225800037384
# The accuracy on this validation set is 0.48559996485710144
# Epoch 91, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.20481981337070465
# The accuracy on this validation set is 0.5039999485015869
# Epoch 92, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.21295498311519623
# The accuracy on this validation set is 0.4949999451637268
# Epoch 93, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.21623562276363373
# The accuracy on this validation set is 0.48179998993873596
# Epoch 94, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.16692820191383362
# The accuracy on this validation set is 0.48959994316101074
# Epoch 95, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.16099531948566437
# The accuracy on this validation set is 0.48799997568130493
# Epoch 96, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.17254166305065155
# The accuracy on this validation set is 0.4827999770641327
# Epoch 97, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.15853376686573029
# The accuracy on this validation set is 0.4959999918937683
# Epoch 98, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.16451463103294373
# The accuracy on this validation set is 0.4917999804019928
# Epoch 99, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.13033421337604523
# The accuracy on this validation set is 0.4927999675273895
# Epoch 100, CIFAR-10 Batch| 1:  accuracy
# The cost on train set is 0.12506946921348572
# The accuracy on this validation set is 0.4877999722957611

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 2.329575777053833
# The accuracy on this validation set is 0.1509999930858612
# Epoch  1, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 2.0972511768341064
# The accuracy on this validation set is 0.26340001821517944
# Epoch  1, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 1.8838651180267334
# The accuracy on this validation set is 0.2881999909877777
# Epoch  1, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 1.8257591724395752
# The accuracy on this validation set is 0.2975999712944031
# Epoch  1, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 1.8922324180603027
# The accuracy on this validation set is 0.3317999839782715
# Epoch  2, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 2.0744943618774414
# The accuracy on this validation set is 0.2903999984264374
# Epoch  2, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 1.903271198272705
# The accuracy on this validation set is 0.3845999538898468
# Epoch  2, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 1.6335393190383911
# The accuracy on this validation set is 0.32580000162124634
# Epoch  2, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 1.666975498199463
# The accuracy on this validation set is 0.38359999656677246
# Epoch  2, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 1.7859153747558594
# The accuracy on this validation set is 0.38040000200271606
# Epoch  3, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 1.8410511016845703
# The accuracy on this validation set is 0.38519999384880066
# Epoch  3, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 1.7640104293823242
# The accuracy on this validation set is 0.4221999943256378
# Epoch  3, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 1.4536662101745605
# The accuracy on this validation set is 0.3790000081062317
# Epoch  3, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 1.5663154125213623
# The accuracy on this validation set is 0.36979997158050537
# Epoch  3, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 1.7352538108825684
# The accuracy on this validation set is 0.43539994955062866
# Epoch  4, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 1.7630316019058228
# The accuracy on this validation set is 0.40939998626708984
# Epoch  4, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 1.6340984106063843
# The accuracy on this validation set is 0.44759994745254517
# Epoch  4, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 1.3529293537139893
# The accuracy on this validation set is 0.42660000920295715
# Epoch  4, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 1.4200162887573242
# The accuracy on this validation set is 0.4213999807834625
# Epoch  4, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 1.6317353248596191
# The accuracy on this validation set is 0.421999990940094
# Epoch  5, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 1.6857218742370605
# The accuracy on this validation set is 0.4445999562740326
# Epoch  5, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 1.5536997318267822
# The accuracy on this validation set is 0.4583999514579773
# Epoch  5, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 1.2902041673660278
# The accuracy on this validation set is 0.44359999895095825
# Epoch  5, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 1.3362452983856201
# The accuracy on this validation set is 0.4599999487400055
# Epoch  5, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 1.5646601915359497
# The accuracy on this validation set is 0.420199990272522
# Epoch  6, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 1.6339516639709473
# The accuracy on this validation set is 0.4381999671459198
# Epoch  6, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 1.498955249786377
# The accuracy on this validation set is 0.4599999487400055
# Epoch  6, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 1.274932861328125
# The accuracy on this validation set is 0.45899999141693115
# Epoch  6, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 1.318730115890503
# The accuracy on this validation set is 0.4779999852180481
# Epoch  6, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 1.4928678274154663
# The accuracy on this validation set is 0.4549999535083771
# Epoch  7, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 1.5983595848083496
# The accuracy on this validation set is 0.4569999575614929
# Epoch  7, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 1.429797649383545
# The accuracy on this validation set is 0.4878000020980835
# Epoch  7, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 1.2821820974349976
# The accuracy on this validation set is 0.48879992961883545
# Epoch  7, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 1.2096819877624512
# The accuracy on this validation set is 0.47039994597435
# Epoch  7, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 1.4212335348129272
# The accuracy on this validation set is 0.4865999221801758
# Epoch  8, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 1.5907783508300781
# The accuracy on this validation set is 0.462399959564209
# Epoch  8, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 1.3988795280456543
# The accuracy on this validation set is 0.504599928855896
# Epoch  8, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 1.2254889011383057
# The accuracy on this validation set is 0.5013999342918396
# Epoch  8, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 1.187005877494812
# The accuracy on this validation set is 0.4899999797344208
# Epoch  8, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 1.3981026411056519
# The accuracy on this validation set is 0.49779996275901794
# Epoch  9, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 1.5701699256896973
# The accuracy on this validation set is 0.47979995608329773
# Epoch  9, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 1.335747480392456
# The accuracy on this validation set is 0.4986000061035156
# Epoch  9, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 1.195874571800232
# The accuracy on this validation set is 0.4957999587059021
# Epoch  9, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 1.1907637119293213
# The accuracy on this validation set is 0.49379995465278625
# Epoch  9, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 1.319381833076477
# The accuracy on this validation set is 0.49599993228912354
# Epoch 10, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 1.4955909252166748
# The accuracy on this validation set is 0.476999968290329
# Epoch 10, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 1.3089263439178467
# The accuracy on this validation set is 0.5245999097824097
# Epoch 10, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 1.1969456672668457
# The accuracy on this validation set is 0.5099999308586121
# Epoch 10, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 1.0974854230880737
# The accuracy on this validation set is 0.5051999092102051
# Epoch 10, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 1.2961337566375732
# The accuracy on this validation set is 0.5179999470710754
# Epoch 11, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 1.425466775894165
# The accuracy on this validation set is 0.49619996547698975
# Epoch 11, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 1.2876954078674316
# The accuracy on this validation set is 0.51419997215271
# Epoch 11, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 1.1421328783035278
# The accuracy on this validation set is 0.5239999294281006
# Epoch 11, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 1.117284893989563
# The accuracy on this validation set is 0.503600001335144
# Epoch 11, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 1.272308349609375
# The accuracy on this validation set is 0.5211999416351318
# Epoch 12, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 1.4097700119018555
# The accuracy on this validation set is 0.51419997215271
# Epoch 12, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 1.1957104206085205
# The accuracy on this validation set is 0.5191999673843384
# Epoch 12, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 1.0972702503204346
# The accuracy on this validation set is 0.5299999713897705
# Epoch 12, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 1.0391089916229248
# The accuracy on this validation set is 0.50819993019104
# Epoch 12, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 1.2075071334838867
# The accuracy on this validation set is 0.5199999213218689
# Epoch 13, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 1.394953966140747
# The accuracy on this validation set is 0.4909999668598175
# Epoch 13, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 1.2085821628570557
# The accuracy on this validation set is 0.5223999619483948
# Epoch 13, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 1.0779575109481812
# The accuracy on this validation set is 0.5309999585151672
# Epoch 13, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.9754551649093628
# The accuracy on this validation set is 0.5283999443054199
# Epoch 13, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 1.1786686182022095
# The accuracy on this validation set is 0.5257999300956726
# Epoch 14, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 1.4444423913955688
# The accuracy on this validation set is 0.5069999694824219
# Epoch 14, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 1.1730165481567383
# The accuracy on this validation set is 0.5053999423980713
# Epoch 14, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 1.03131103515625
# The accuracy on this validation set is 0.5311999320983887
# Epoch 14, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.9479043483734131
# The accuracy on this validation set is 0.521399974822998
# Epoch 14, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 1.1299412250518799
# The accuracy on this validation set is 0.5367999076843262
# Epoch 15, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 1.41813063621521
# The accuracy on this validation set is 0.5095999240875244
# Epoch 15, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 1.068557858467102
# The accuracy on this validation set is 0.5333999395370483
# Epoch 15, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 1.03097665309906
# The accuracy on this validation set is 0.5381999015808105
# Epoch 15, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.9476660490036011
# The accuracy on this validation set is 0.5155999064445496
# Epoch 15, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 1.075867772102356
# The accuracy on this validation set is 0.5259999632835388
# Epoch 16, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 1.3619940280914307
# The accuracy on this validation set is 0.5163999795913696
# Epoch 16, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 1.080053448677063
# The accuracy on this validation set is 0.5135999321937561
# Epoch 16, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.9596307873725891
# The accuracy on this validation set is 0.531999945640564
# Epoch 16, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.8803239464759827
# The accuracy on this validation set is 0.5335999131202698
# Epoch 16, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 1.144788146018982
# The accuracy on this validation set is 0.5401999354362488
# Epoch 17, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 1.303147315979004
# The accuracy on this validation set is 0.5221999883651733
# Epoch 17, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.9957051277160645
# The accuracy on this validation set is 0.5301999449729919
# Epoch 17, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.9314673542976379
# The accuracy on this validation set is 0.5427999496459961
# Epoch 17, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.8206881284713745
# The accuracy on this validation set is 0.5425999164581299
# Epoch 17, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 1.1567652225494385
# The accuracy on this validation set is 0.5517999529838562
# Epoch 18, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 1.2613325119018555
# The accuracy on this validation set is 0.5211999416351318
# Epoch 18, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.9363560676574707
# The accuracy on this validation set is 0.5363999605178833
# Epoch 18, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.9086831212043762
# The accuracy on this validation set is 0.5433999300003052
# Epoch 18, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.7989110946655273
# The accuracy on this validation set is 0.5473999381065369
# Epoch 18, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 1.0924946069717407
# The accuracy on this validation set is 0.5447998642921448
# Epoch 19, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 1.175411581993103
# The accuracy on this validation set is 0.5407999753952026
# Epoch 19, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.9133018255233765
# The accuracy on this validation set is 0.5493999719619751
# Epoch 19, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.8715741634368896
# The accuracy on this validation set is 0.545199990272522
# Epoch 19, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.800106406211853
# The accuracy on this validation set is 0.5369999408721924
# Epoch 19, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 1.0085738897323608
# The accuracy on this validation set is 0.5583999156951904
# Epoch 20, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 1.1738592386245728
# The accuracy on this validation set is 0.522599995136261
# Epoch 20, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.8934124708175659
# The accuracy on this validation set is 0.5483999252319336
# Epoch 20, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.8642358779907227
# The accuracy on this validation set is 0.5447999238967896
# Epoch 20, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.7771605849266052
# The accuracy on this validation set is 0.5441999435424805
# Epoch 20, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.9681873321533203
# The accuracy on this validation set is 0.555199921131134
# Epoch 21, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 1.0644819736480713
# The accuracy on this validation set is 0.5347999334335327
# Epoch 21, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.8985233306884766
# The accuracy on this validation set is 0.5377999544143677
# Epoch 21, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.8248714208602905
# The accuracy on this validation set is 0.5493999719619751
# Epoch 21, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.7798669338226318
# The accuracy on this validation set is 0.5483999252319336
# Epoch 21, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.9935168027877808
# The accuracy on this validation set is 0.5493999719619751
# Epoch 22, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 1.0140459537506104
# The accuracy on this validation set is 0.5379999279975891
# Epoch 22, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.7975716590881348
# The accuracy on this validation set is 0.5407999157905579
# Epoch 22, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.8431395292282104
# The accuracy on this validation set is 0.5367999076843262
# Epoch 22, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.7317650318145752
# The accuracy on this validation set is 0.5465999245643616
# Epoch 22, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.8390004634857178
# The accuracy on this validation set is 0.5451998710632324
# Epoch 23, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.902900755405426
# The accuracy on this validation set is 0.5349999070167542
# Epoch 23, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.8811089396476746
# The accuracy on this validation set is 0.5211999416351318
# Epoch 23, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.8283907175064087
# The accuracy on this validation set is 0.536799967288971
# Epoch 23, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.7497761249542236
# The accuracy on this validation set is 0.5419999361038208
# Epoch 23, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.8434507846832275
# The accuracy on this validation set is 0.5541999340057373
# Epoch 24, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.8837757110595703
# The accuracy on this validation set is 0.5351999402046204
# Epoch 24, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.7519783973693848
# The accuracy on this validation set is 0.5357999801635742
# Epoch 24, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.7129698395729065
# The accuracy on this validation set is 0.530799925327301
# Epoch 24, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.6509672403335571
# The accuracy on this validation set is 0.5447999835014343
# Epoch 24, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.7825393676757812
# The accuracy on this validation set is 0.556999921798706
# Epoch 25, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.88614422082901
# The accuracy on this validation set is 0.546799898147583
# Epoch 25, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.8035492897033691
# The accuracy on this validation set is 0.5261999368667603
# Epoch 25, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.7167498469352722
# The accuracy on this validation set is 0.5313999652862549
# Epoch 25, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.67311692237854
# The accuracy on this validation set is 0.5403999090194702
# Epoch 25, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.7607182860374451
# The accuracy on this validation set is 0.5649999380111694
# Epoch 26, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.8781452178955078
# The accuracy on this validation set is 0.5407999753952026
# Epoch 26, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.6749023199081421
# The accuracy on this validation set is 0.5511999130249023
# Epoch 26, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.6282123327255249
# The accuracy on this validation set is 0.5333999395370483
# Epoch 26, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.6125440001487732
# The accuracy on this validation set is 0.5449999570846558
# Epoch 26, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.8091053366661072
# The accuracy on this validation set is 0.5527999401092529
# Epoch 27, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.8254932165145874
# The accuracy on this validation set is 0.5441999435424805
# Epoch 27, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.6653540730476379
# The accuracy on this validation set is 0.5571999549865723
# Epoch 27, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.5890699625015259
# The accuracy on this validation set is 0.5357999801635742
# Epoch 27, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.6207589507102966
# The accuracy on this validation set is 0.5439999103546143
# Epoch 27, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.7609663009643555
# The accuracy on this validation set is 0.5557999014854431
# Epoch 28, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.908268928527832
# The accuracy on this validation set is 0.5477998852729797
# Epoch 28, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.6729406118392944
# The accuracy on this validation set is 0.5559999346733093
# Epoch 28, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.610400915145874
# The accuracy on this validation set is 0.5265999436378479
# Epoch 28, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.5788111686706543
# The accuracy on this validation set is 0.5553999543190002
# Epoch 28, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.7072525024414062
# The accuracy on this validation set is 0.5535999536514282
# Epoch 29, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.794232189655304
# The accuracy on this validation set is 0.5573999285697937
# Epoch 29, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.614511251449585
# The accuracy on this validation set is 0.5667999386787415
# Epoch 29, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.5449171662330627
# The accuracy on this validation set is 0.5371999740600586
# Epoch 29, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.5813957452774048
# The accuracy on this validation set is 0.5603999495506287
# Epoch 29, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.727902889251709
# The accuracy on this validation set is 0.5595999360084534
# Epoch 30, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.8432997465133667
# The accuracy on this validation set is 0.5577999353408813
# Epoch 30, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.549982488155365
# The accuracy on this validation set is 0.5489999055862427
# Epoch 30, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.5890387296676636
# The accuracy on this validation set is 0.5321999192237854
# Epoch 30, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.607799768447876
# The accuracy on this validation set is 0.5511999130249023
# Epoch 30, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.6955808997154236
# The accuracy on this validation set is 0.5641999244689941
# Epoch 31, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.8403229713439941
# The accuracy on this validation set is 0.5539999008178711
# Epoch 31, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.5601226687431335
# The accuracy on this validation set is 0.5549999475479126
# Epoch 31, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.5458148717880249
# The accuracy on this validation set is 0.5389999151229858
# Epoch 31, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.5826399326324463
# The accuracy on this validation set is 0.561199963092804
# Epoch 31, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.6493076086044312
# The accuracy on this validation set is 0.568199872970581
# Epoch 32, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.8383100032806396
# The accuracy on this validation set is 0.5665999054908752
# Epoch 32, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.5121785998344421
# The accuracy on this validation set is 0.555199921131134
# Epoch 32, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.49838048219680786
# The accuracy on this validation set is 0.5443999171257019
# Epoch 32, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.5325663685798645
# The accuracy on this validation set is 0.5627999305725098
# Epoch 32, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.5951662063598633
# The accuracy on this validation set is 0.5585999488830566
# Epoch 33, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.7575118541717529
# The accuracy on this validation set is 0.5639999508857727
# Epoch 33, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.48035097122192383
# The accuracy on this validation set is 0.5667998790740967
# Epoch 33, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.5225722789764404
# The accuracy on this validation set is 0.542199969291687
# Epoch 33, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.5353358387947083
# The accuracy on this validation set is 0.5655999183654785
# Epoch 33, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.5806984901428223
# The accuracy on this validation set is 0.5715999007225037
# Epoch 34, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.717796266078949
# The accuracy on this validation set is 0.5651999115943909
# Epoch 34, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.4320929944515228
# The accuracy on this validation set is 0.554599940776825
# Epoch 34, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.5218303203582764
# The accuracy on this validation set is 0.5323999524116516
# Epoch 34, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.4715273976325989
# The accuracy on this validation set is 0.5611999034881592
# Epoch 34, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.5353215336799622
# The accuracy on this validation set is 0.5603999495506287
# Epoch 35, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.6718802452087402
# The accuracy on this validation set is 0.5637999176979065
# Epoch 35, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.5240141749382019
# The accuracy on this validation set is 0.5653999447822571
# Epoch 35, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.45460450649261475
# The accuracy on this validation set is 0.536799967288971
# Epoch 35, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.42628467082977295
# The accuracy on this validation set is 0.5745999217033386
# Epoch 35, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.6396357417106628
# The accuracy on this validation set is 0.5733999013900757
# Epoch 36, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.6926983594894409
# The accuracy on this validation set is 0.5587999224662781
# Epoch 36, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.4633466601371765
# The accuracy on this validation set is 0.5725998878479004
# Epoch 36, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.4864700436592102
# The accuracy on this validation set is 0.5365999341011047
# Epoch 36, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.4256327152252197
# The accuracy on this validation set is 0.5637999176979065
# Epoch 36, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.5947669744491577
# The accuracy on this validation set is 0.5583999156951904
# Epoch 37, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.5855544805526733
# The accuracy on this validation set is 0.5635999441146851
# Epoch 37, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.39205706119537354
# The accuracy on this validation set is 0.5695999264717102
# Epoch 37, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.45532578229904175
# The accuracy on this validation set is 0.5493999719619751
# Epoch 37, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.4113982915878296
# The accuracy on this validation set is 0.5801999568939209
# Epoch 37, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.5083828568458557
# The accuracy on this validation set is 0.5715999007225037
# Epoch 38, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.599575400352478
# The accuracy on this validation set is 0.5579999089241028
# Epoch 38, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.4244099259376526
# The accuracy on this validation set is 0.5661998987197876
# Epoch 38, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.39313215017318726
# The accuracy on this validation set is 0.5393998622894287
# Epoch 38, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.41185957193374634
# The accuracy on this validation set is 0.5525999069213867
# Epoch 38, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.43557503819465637
# The accuracy on this validation set is 0.5883998870849609
# Epoch 39, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.5621105432510376
# The accuracy on this validation set is 0.5751998424530029
# Epoch 39, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.4144012928009033
# The accuracy on this validation set is 0.573199987411499
# Epoch 39, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.421661376953125
# The accuracy on this validation set is 0.561799943447113
# Epoch 39, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.40690261125564575
# The accuracy on this validation set is 0.5737998485565186
# Epoch 39, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.41669636964797974
# The accuracy on this validation set is 0.5721999406814575
# Epoch 40, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.5525007247924805
# The accuracy on this validation set is 0.5723998546600342
# Epoch 40, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.38681262731552124
# The accuracy on this validation set is 0.5705999135971069
# Epoch 40, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.540072500705719
# The accuracy on this validation set is 0.5633999109268188
# Epoch 40, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.417349636554718
# The accuracy on this validation set is 0.5719999074935913
# Epoch 40, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.400505393743515
# The accuracy on this validation set is 0.5713999271392822
# Epoch 41, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.49178749322891235
# The accuracy on this validation set is 0.5705999135971069
# Epoch 41, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.38680240511894226
# The accuracy on this validation set is 0.5721999406814575
# Epoch 41, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.4850768744945526
# The accuracy on this validation set is 0.5655999183654785
# Epoch 41, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.3650858998298645
# The accuracy on this validation set is 0.5765998363494873
# Epoch 41, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.3911059498786926
# The accuracy on this validation set is 0.572399914264679
# Epoch 42, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.4937033951282501
# The accuracy on this validation set is 0.5721998810768127
# Epoch 42, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.4180099666118622
# The accuracy on this validation set is 0.5769999027252197
# Epoch 42, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.5534396171569824
# The accuracy on this validation set is 0.5831999778747559
# Epoch 42, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.35522013902664185
# The accuracy on this validation set is 0.5761998891830444
# Epoch 42, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.40462061762809753
# The accuracy on this validation set is 0.5747999548912048
# Epoch 43, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.44505074620246887
# The accuracy on this validation set is 0.5681999325752258
# Epoch 43, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.5640439987182617
# The accuracy on this validation set is 0.5791999697685242
# Epoch 43, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.46757930517196655
# The accuracy on this validation set is 0.5781998634338379
# Epoch 43, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.32066524028778076
# The accuracy on this validation set is 0.5725999474525452
# Epoch 43, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.4117621183395386
# The accuracy on this validation set is 0.56659996509552
# Epoch 44, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.4858672022819519
# The accuracy on this validation set is 0.5631999373435974
# Epoch 44, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.5078079104423523
# The accuracy on this validation set is 0.5899999141693115
# Epoch 44, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.4787631332874298
# The accuracy on this validation set is 0.5797998905181885
# Epoch 44, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.3348234295845032
# The accuracy on this validation set is 0.5701999068260193
# Epoch 44, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.3585699796676636
# The accuracy on this validation set is 0.5729999542236328
# Epoch 45, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.3888443410396576
# The accuracy on this validation set is 0.5641999244689941
# Epoch 45, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.3828176259994507
# The accuracy on this validation set is 0.5891999006271362
# Epoch 45, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.37536466121673584
# The accuracy on this validation set is 0.5647999048233032
# Epoch 45, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.29124921560287476
# The accuracy on this validation set is 0.5837998986244202
# Epoch 45, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.274753212928772
# The accuracy on this validation set is 0.5765999555587769
# Epoch 46, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.48948317766189575
# The accuracy on this validation set is 0.562999963760376
# Epoch 46, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.3939768373966217
# The accuracy on this validation set is 0.5821998715400696
# Epoch 46, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.38216885924339294
# The accuracy on this validation set is 0.5735999345779419
# Epoch 46, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.27463188767433167
# The accuracy on this validation set is 0.5787999033927917
# Epoch 46, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.28574052453041077
# The accuracy on this validation set is 0.5829998850822449
# Epoch 47, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.42693790793418884
# The accuracy on this validation set is 0.5681999325752258
# Epoch 47, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.35892269015312195
# The accuracy on this validation set is 0.5893999338150024
# Epoch 47, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.3732616901397705
# The accuracy on this validation set is 0.575999915599823
# Epoch 47, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.2717786431312561
# The accuracy on this validation set is 0.5725998878479004
# Epoch 47, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.31838351488113403
# The accuracy on this validation set is 0.5863999724388123
# Epoch 48, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.3984854817390442
# The accuracy on this validation set is 0.5721999406814575
# Epoch 48, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.3797145485877991
# The accuracy on this validation set is 0.5871999263763428
# Epoch 48, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.343548059463501
# The accuracy on this validation set is 0.5765999555587769
# Epoch 48, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.2851545214653015
# The accuracy on this validation set is 0.5689999461174011
# Epoch 48, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.2576654553413391
# The accuracy on this validation set is 0.5749999284744263
# Epoch 49, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.4284357726573944
# The accuracy on this validation set is 0.5725998878479004
# Epoch 49, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.34657299518585205
# The accuracy on this validation set is 0.5823999047279358
# Epoch 49, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.31424832344055176
# The accuracy on this validation set is 0.5633999109268188
# Epoch 49, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.26087164878845215
# The accuracy on this validation set is 0.5587999224662781
# Epoch 49, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.2738630771636963
# The accuracy on this validation set is 0.5831999182701111
# Epoch 50, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.3891402781009674
# The accuracy on this validation set is 0.571199893951416
# Epoch 50, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.308712899684906
# The accuracy on this validation set is 0.5807998776435852
# Epoch 50, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.2949322760105133
# The accuracy on this validation set is 0.564799964427948
# Epoch 50, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.21576789021492004
# The accuracy on this validation set is 0.5691999197006226
# Epoch 50, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.2867893874645233
# The accuracy on this validation set is 0.5787999629974365
# Epoch 51, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.42396414279937744
# The accuracy on this validation set is 0.5745999217033386
# Epoch 51, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.23636120557785034
# The accuracy on this validation set is 0.5785999298095703
# Epoch 51, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.2584018111228943
# The accuracy on this validation set is 0.5645999908447266
# Epoch 51, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.20570287108421326
# The accuracy on this validation set is 0.5701999068260193
# Epoch 51, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.24867823719978333
# The accuracy on this validation set is 0.5817999839782715
# Epoch 52, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.45489880442619324
# The accuracy on this validation set is 0.5725999474525452
# Epoch 52, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.2956835925579071
# The accuracy on this validation set is 0.5835999250411987
# Epoch 52, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.2806050181388855
# The accuracy on this validation set is 0.5733999013900757
# Epoch 52, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.2274942547082901
# The accuracy on this validation set is 0.5537998676300049
# Epoch 52, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.2701418995857239
# The accuracy on this validation set is 0.5781999826431274
# Epoch 53, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.3372356593608856
# The accuracy on this validation set is 0.5653998851776123
# Epoch 53, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.26149171590805054
# The accuracy on this validation set is 0.5739998817443848
# Epoch 53, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.25343266129493713
# The accuracy on this validation set is 0.5719999074935913
# Epoch 53, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.22688403725624084
# The accuracy on this validation set is 0.5517998933792114
# Epoch 53, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.26699554920196533
# The accuracy on this validation set is 0.5781999826431274
# Epoch 54, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.4134979248046875
# The accuracy on this validation set is 0.5743998885154724
# Epoch 54, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.3095994293689728
# The accuracy on this validation set is 0.5767999291419983
# Epoch 54, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.21865852177143097
# The accuracy on this validation set is 0.5769999623298645
# Epoch 54, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.2124258279800415
# The accuracy on this validation set is 0.5541999340057373
# Epoch 54, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.2486623227596283
# The accuracy on this validation set is 0.5751999020576477
# Epoch 55, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.35280123353004456
# The accuracy on this validation set is 0.5781999230384827
# Epoch 55, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.2773370146751404
# The accuracy on this validation set is 0.5615999698638916
# Epoch 55, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.2777915298938751
# The accuracy on this validation set is 0.5667999386787415
# Epoch 55, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.1988765299320221
# The accuracy on this validation set is 0.5449999570846558
# Epoch 55, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.21680530905723572
# The accuracy on this validation set is 0.5783999562263489
# Epoch 56, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.38365477323532104
# The accuracy on this validation set is 0.5817999243736267
# Epoch 56, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.21485212445259094
# The accuracy on this validation set is 0.5775999426841736
# Epoch 56, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.25966334342956543
# The accuracy on this validation set is 0.561799943447113
# Epoch 56, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.20284749567508698
# The accuracy on this validation set is 0.5511999130249023
# Epoch 56, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.19144701957702637
# The accuracy on this validation set is 0.5743999481201172
# Epoch 57, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.3046131134033203
# The accuracy on this validation set is 0.5747998952865601
# Epoch 57, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.28293249011039734
# The accuracy on this validation set is 0.5567998886108398
# Epoch 57, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.2377791702747345
# The accuracy on this validation set is 0.5591999292373657
# Epoch 57, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.1970883458852768
# The accuracy on this validation set is 0.5495998859405518
# Epoch 57, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.19053949415683746
# The accuracy on this validation set is 0.5679998993873596
# Epoch 58, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.2955307066440582
# The accuracy on this validation set is 0.5763999223709106
# Epoch 58, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.25566616654396057
# The accuracy on this validation set is 0.5579999089241028
# Epoch 58, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.20509524643421173
# The accuracy on this validation set is 0.5641999244689941
# Epoch 58, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.19350633025169373
# The accuracy on this validation set is 0.5445999503135681
# Epoch 58, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.21937152743339539
# The accuracy on this validation set is 0.5733999013900757
# Epoch 59, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.24766328930854797
# The accuracy on this validation set is 0.5829998850822449
# Epoch 59, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.22419080138206482
# The accuracy on this validation set is 0.5517998933792114
# Epoch 59, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.1771874874830246
# The accuracy on this validation set is 0.559999942779541
# Epoch 59, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.19512131810188293
# The accuracy on this validation set is 0.5463998913764954
# Epoch 59, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.17635676264762878
# The accuracy on this validation set is 0.5749999284744263
# Epoch 60, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.24808037281036377
# The accuracy on this validation set is 0.5763999223709106
# Epoch 60, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.2146121710538864
# The accuracy on this validation set is 0.5383999347686768
# Epoch 60, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.1804753839969635
# The accuracy on this validation set is 0.5633999109268188
# Epoch 60, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.19708941876888275
# The accuracy on this validation set is 0.545799970626831
# Epoch 60, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.1913478970527649
# The accuracy on this validation set is 0.5691999197006226
# Epoch 61, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.24612177908420563
# The accuracy on this validation set is 0.5833998918533325
# Epoch 61, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.2168002724647522
# The accuracy on this validation set is 0.5410000085830688
# Epoch 61, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.1758110225200653
# The accuracy on this validation set is 0.5503999590873718
# Epoch 61, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.20515212416648865
# The accuracy on this validation set is 0.5451999306678772
# Epoch 61, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.17026442289352417
# The accuracy on this validation set is 0.5729999542236328
# Epoch 62, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.20651745796203613
# The accuracy on this validation set is 0.5731999278068542
# Epoch 62, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.2002347707748413
# The accuracy on this validation set is 0.5445999503135681
# Epoch 62, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.1703103631734848
# The accuracy on this validation set is 0.5425999164581299
# Epoch 62, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.1888473480939865
# The accuracy on this validation set is 0.5487999320030212
# Epoch 62, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.1581917256116867
# The accuracy on this validation set is 0.5721999406814575
# Epoch 63, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.232903853058815
# The accuracy on this validation set is 0.5755999088287354
# Epoch 63, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.16636814177036285
# The accuracy on this validation set is 0.5559999346733093
# Epoch 63, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.13265874981880188
# The accuracy on this validation set is 0.5555999279022217
# Epoch 63, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.14966493844985962
# The accuracy on this validation set is 0.5487999320030212
# Epoch 63, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.12913557887077332
# The accuracy on this validation set is 0.5703999400138855
# Epoch 64, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.16152718663215637
# The accuracy on this validation set is 0.574199914932251
# Epoch 64, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.16761258244514465
# The accuracy on this validation set is 0.5463999509811401
# Epoch 64, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.16594909131526947
# The accuracy on this validation set is 0.553399920463562
# Epoch 64, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.10881932824850082
# The accuracy on this validation set is 0.5589998960494995
# Epoch 64, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.12721306085586548
# The accuracy on this validation set is 0.5717999339103699
# Epoch 65, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.17927490174770355
# The accuracy on this validation set is 0.5735999345779419
# Epoch 65, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.09820825606584549
# The accuracy on this validation set is 0.5679998993873596
# Epoch 65, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.12671764194965363
# The accuracy on this validation set is 0.5585999488830566
# Epoch 65, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.10948096215724945
# The accuracy on this validation set is 0.5625998973846436
# Epoch 65, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.11979466676712036
# The accuracy on this validation set is 0.5715999603271484
# Epoch 66, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.13578155636787415
# The accuracy on this validation set is 0.5763999223709106
# Epoch 66, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.10206493735313416
# The accuracy on this validation set is 0.5717999339103699
# Epoch 66, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.12022843956947327
# The accuracy on this validation set is 0.5529999732971191
# Epoch 66, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.10855209827423096
# The accuracy on this validation set is 0.5621999502182007
# Epoch 66, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.12994146347045898
# The accuracy on this validation set is 0.5783998966217041
# Epoch 67, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.12104335427284241
# The accuracy on this validation set is 0.5689999461174011
# Epoch 67, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.10060079395771027
# The accuracy on this validation set is 0.5707999467849731
# Epoch 67, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.12962943315505981
# The accuracy on this validation set is 0.5389999151229858
# Epoch 67, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.13521535694599152
# The accuracy on this validation set is 0.572999894618988
# Epoch 67, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.13969635963439941
# The accuracy on this validation set is 0.579599916934967
# Epoch 68, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.1847335547208786
# The accuracy on this validation set is 0.569599986076355
# Epoch 68, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.07537346333265305
# The accuracy on this validation set is 0.5691999197006226
# Epoch 68, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.10290282964706421
# The accuracy on this validation set is 0.5385999083518982
# Epoch 68, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.1448969542980194
# The accuracy on this validation set is 0.5549998879432678
# Epoch 68, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.1303757280111313
# The accuracy on this validation set is 0.5813999772071838
# ...
# The accuracy on this validation set is 0.5575999021530151
# Epoch 78, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.05040937662124634
# The accuracy on this validation set is 0.5865999460220337
# Epoch 78, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.11887223273515701
# The accuracy on this validation set is 0.5687999725341797
# Epoch 79, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.06735183298587799
# The accuracy on this validation set is 0.56659996509552
# Epoch 79, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.06639086455106735
# The accuracy on this validation set is 0.5757999420166016
# Epoch 79, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.07751421630382538
# The accuracy on this validation set is 0.5573999285697937
# Epoch 79, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.07016915082931519
# The accuracy on this validation set is 0.5801998972892761
# Epoch 79, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.14279846847057343
# The accuracy on this validation set is 0.5649999380111694
# Epoch 80, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.08616482466459274
# The accuracy on this validation set is 0.5721999406814575
# Epoch 80, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.03672049194574356
# The accuracy on this validation set is 0.5633999705314636
# Epoch 80, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.06715631484985352
# The accuracy on this validation set is 0.5581998825073242
# Epoch 80, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.05146583914756775
# The accuracy on this validation set is 0.5835999250411987
# Epoch 80, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.14477328956127167
# The accuracy on this validation set is 0.5749999284744263
# Epoch 81, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.06509393453598022
# The accuracy on this validation set is 0.5637999176979065
# Epoch 81, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.03259621560573578
# The accuracy on this validation set is 0.5739999413490295
# Epoch 81, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.06801671534776688
# The accuracy on this validation set is 0.5615999102592468
# Epoch 81, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.06520544737577438
# The accuracy on this validation set is 0.5827999711036682
# Epoch 81, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.0842285007238388
# The accuracy on this validation set is 0.5687999129295349
# Epoch 82, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.04614199697971344
# The accuracy on this validation set is 0.5607999563217163
# Epoch 82, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.02495630457997322
# The accuracy on this validation set is 0.5701999068260193
# Epoch 82, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.06252416223287582
# The accuracy on this validation set is 0.5619999170303345
# Epoch 82, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.04533413052558899
# The accuracy on this validation set is 0.5785998702049255
# Epoch 82, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.06253396719694138
# The accuracy on this validation set is 0.56659996509552
# Epoch 83, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.062007494270801544
# The accuracy on this validation set is 0.5613999366760254
# Epoch 83, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.0326332189142704
# The accuracy on this validation set is 0.5759999752044678
# Epoch 83, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.049262095242738724
# The accuracy on this validation set is 0.5547999739646912
# Epoch 83, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.046868421137332916
# The accuracy on this validation set is 0.5755999684333801
# Epoch 83, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.09615755081176758
# The accuracy on this validation set is 0.5529999136924744
# Epoch 84, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.043645039200782776
# The accuracy on this validation set is 0.5589998960494995
# Epoch 84, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.03978908434510231
# The accuracy on this validation set is 0.5631998777389526
# Epoch 84, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.060589127242565155
# The accuracy on this validation set is 0.5539999008178711
# Epoch 84, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.03817794844508171
# The accuracy on this validation set is 0.5847998857498169
# Epoch 84, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.09115464240312576
# The accuracy on this validation set is 0.5597999095916748
# Epoch 85, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.03346201032400131
# The accuracy on this validation set is 0.5577999353408813
# Epoch 85, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.04230480268597603
# The accuracy on this validation set is 0.5715999603271484
# Epoch 85, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.04561641812324524
# The accuracy on this validation set is 0.556399941444397
# Epoch 85, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.03695378825068474
# The accuracy on this validation set is 0.5855998992919922
# Epoch 85, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.06546890735626221
# The accuracy on this validation set is 0.5689998865127563
# Epoch 86, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.027752095833420753
# The accuracy on this validation set is 0.5587999224662781
# Epoch 86, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.02885700762271881
# The accuracy on this validation set is 0.5705999732017517
# Epoch 86, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.055785611271858215
# The accuracy on this validation set is 0.556999921798706
# Epoch 86, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.03291132673621178
# The accuracy on this validation set is 0.5865999460220337
# Epoch 86, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.06968996673822403
# The accuracy on this validation set is 0.5649999380111694
# Epoch 87, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.026407938450574875
# The accuracy on this validation set is 0.559999942779541
# Epoch 87, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.04271557554602623
# The accuracy on this validation set is 0.5667998790740967
# Epoch 87, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.03965046629309654
# The accuracy on this validation set is 0.5703999996185303
# Epoch 87, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.0388924740254879
# The accuracy on this validation set is 0.5797999501228333
# Epoch 87, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.030043214559555054
# The accuracy on this validation set is 0.5729999542236328
# Epoch 88, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.038213588297367096
# The accuracy on this validation set is 0.5703998804092407
# Epoch 88, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.028863318264484406
# The accuracy on this validation set is 0.5717999339103699
# Epoch 88, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.05297792702913284
# The accuracy on this validation set is 0.5639998912811279
# Epoch 88, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.028162134811282158
# The accuracy on this validation set is 0.5897998809814453
# Epoch 88, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.08002687990665436
# The accuracy on this validation set is 0.5571999549865723
# Epoch 89, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.0602898970246315
# The accuracy on this validation set is 0.5591999292373657
# Epoch 89, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.023415839299559593
# The accuracy on this validation set is 0.572999894618988
# Epoch 89, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.04657093435525894
# The accuracy on this validation set is 0.5595998764038086
# Epoch 89, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.035149600356817245
# The accuracy on this validation set is 0.5877999067306519
# Epoch 89, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.07138124108314514
# The accuracy on this validation set is 0.56659996509552
# Epoch 90, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.03449639305472374
# The accuracy on this validation set is 0.5665999054908752
# Epoch 90, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.0330343134701252
# The accuracy on this validation set is 0.5649999380111694
# Epoch 90, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.049705423414707184
# The accuracy on this validation set is 0.5717999339103699
# Epoch 90, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.026105370372533798
# The accuracy on this validation set is 0.5837998986244202
# Epoch 90, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.039173293858766556
# The accuracy on this validation set is 0.5685999393463135
# Epoch 91, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.029714643955230713
# The accuracy on this validation set is 0.574199914932251
# Epoch 91, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.024817408993840218
# The accuracy on this validation set is 0.5649999380111694
# Epoch 91, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.038078904151916504
# The accuracy on this validation set is 0.5647999048233032
# Epoch 91, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.026732604950666428
# The accuracy on this validation set is 0.585599958896637
# Epoch 91, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.04416251182556152
# The accuracy on this validation set is 0.5679999589920044
# Epoch 92, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.026279930025339127
# The accuracy on this validation set is 0.5671999454498291
# Epoch 92, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.0362403579056263
# The accuracy on this validation set is 0.5593999624252319
# Epoch 92, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.0400988906621933
# The accuracy on this validation set is 0.5671999454498291
# Epoch 92, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.02279381826519966
# The accuracy on this validation set is 0.5865999460220337
# Epoch 92, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.03223700821399689
# The accuracy on this validation set is 0.5637999773025513
# Epoch 93, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.06748690456151962
# The accuracy on this validation set is 0.5679999589920044
# Epoch 93, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.021011171862483025
# The accuracy on this validation set is 0.5583999752998352
# Epoch 93, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.046125613152980804
# The accuracy on this validation set is 0.5655999183654785
# Epoch 93, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.021974746137857437
# The accuracy on this validation set is 0.5849999785423279
# Epoch 93, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.04934040457010269
# The accuracy on this validation set is 0.5677999258041382
# Epoch 94, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.026985758915543556
# The accuracy on this validation set is 0.5695999264717102
# Epoch 94, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.012920279055833817
# The accuracy on this validation set is 0.5597999095916748
# Epoch 94, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.043409593403339386
# The accuracy on this validation set is 0.5711999535560608
# Epoch 94, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.026066480204463005
# The accuracy on this validation set is 0.5867999196052551
# Epoch 94, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.030400101095438004
# The accuracy on this validation set is 0.5755999684333801
# Epoch 95, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.039061568677425385
# The accuracy on this validation set is 0.577799916267395
# Epoch 95, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.039747726172208786
# The accuracy on this validation set is 0.5485999584197998
# Epoch 95, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.04514184221625328
# The accuracy on this validation set is 0.5639999508857727
# Epoch 95, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.025616217404603958
# The accuracy on this validation set is 0.5901999473571777
# Epoch 95, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.03999785706400871
# The accuracy on this validation set is 0.5737999677658081
# Epoch 96, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.0405079685151577
# The accuracy on this validation set is 0.5583999156951904
# Epoch 96, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.028322525322437286
# The accuracy on this validation set is 0.5531999468803406
# Epoch 96, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.039499394595623016
# The accuracy on this validation set is 0.5589998960494995
# Epoch 96, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.020756013691425323
# The accuracy on this validation set is 0.5827999114990234
# Epoch 96, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.03772439435124397
# The accuracy on this validation set is 0.5551999807357788
# Epoch 97, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.07604134827852249
# The accuracy on this validation set is 0.5509999394416809
# Epoch 97, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.02263309620320797
# The accuracy on this validation set is 0.555199921131134
# Epoch 97, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.029994884505867958
# The accuracy on this validation set is 0.5585998892784119
# Epoch 97, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.022935030981898308
# The accuracy on this validation set is 0.5911998748779297
# Epoch 97, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.023894893005490303
# The accuracy on this validation set is 0.5705999135971069
# Epoch 98, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.06249985843896866
# The accuracy on this validation set is 0.5625998973846436
# Epoch 98, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.026728132739663124
# The accuracy on this validation set is 0.559999942779541
# Epoch 98, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.026619015261530876
# The accuracy on this validation set is 0.5645999908447266
# Epoch 98, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.024557942524552345
# The accuracy on this validation set is 0.5897999405860901
# Epoch 98, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.025183483958244324
# The accuracy on this validation set is 0.5737999677658081
# Epoch 99, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.02573160082101822
# The accuracy on this validation set is 0.5605999827384949
# Epoch 99, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.0292929969727993
# The accuracy on this validation set is 0.5407999753952026
# Epoch 99, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.03498677909374237
# The accuracy on this validation set is 0.5679999589920044
# Epoch 99, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.018634308129549026
# The accuracy on this validation set is 0.5933999419212341
# Epoch 99, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.03394049406051636
# The accuracy on this validation set is 0.5763999223709106
# Epoch 100, CIFAR-10 Batch 1:  accuracy
# The cost on train set is 0.03636926785111427
# The accuracy on this validation set is 0.5723999738693237
# Epoch 100, CIFAR-10 Batch 2:  accuracy
# The cost on train set is 0.013995597139000893
# The accuracy on this validation set is 0.5535999536514282
# Epoch 100, CIFAR-10 Batch 3:  accuracy
# The cost on train set is 0.0516609251499176
# The accuracy on this validation set is 0.5583999156951904
# Epoch 100, CIFAR-10 Batch 4:  accuracy
# The cost on train set is 0.028520138934254646
# The accuracy on this validation set is 0.590199887752533
# Epoch 100, CIFAR-10 Batch 5:  accuracy
# The cost on train set is 0.031463153660297394
# The accuracy on this validation set is 0.5689998865127563

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.6119625796178344

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
